# %% [markdown]
# # Plotting percentatge of mountain incidents acted by the fire departement

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

# %% [markdown]
# ## Importing correlated incidents with fire departement actions

# %%
direct = 'csv_files/'

df = pd.read_csv(direct + 'Correlations_fire-112.csv')
df['CODI_COMARCA'] = df['CODI_COMARCA'].astype(str).str.zfill(2)
df
# Out:
#          ANY-MES            COMARCA  INCIDENTS CODI_COMARCA  SALVAMENTS
# 0     2018-01-01        ALT EMPORDA        814           02           3
# 1     2018-01-01        ALT PENEDES        597           03           2
# 2     2018-01-01         ALT URGELL        106           04           1
# 3     2018-01-01              ANOIA        576           06           3
# 4     2018-01-01              BAGES        943           07           6
# ...          ...                ...        ...          ...         ...
# 1939  2022-12-01         TARRAGONES       2275           36           1
# 1940  2022-12-01         TERRA ALTA         40           37           2
# 1941  2022-12-01         VAL D'ARAN         67           39           9
# 1942  2022-12-01  VALLES OCCIDENTAL       6202           40           6
# 1943  2022-12-01    VALLES ORIENTAL       2538           41           3
#
# [1944 rows x 5 columns]

# %%
def percentatge(x,y):
    p = x/y*100
    return p

data=df.copy()

data['PERCENTATGE'] = data.apply(lambda row: percentatge(row['SALVAMENTS'], row['INCIDENTS']), axis=1)

data

# results= data[data['COMARCA']=='BERGUEDA']
# results
# Out:
#          ANY-MES            COMARCA  INCIDENTS CODI_COMARCA  SALVAMENTS  \
# 0     2018-01-01        ALT EMPORDA        814           02           3
# 1     2018-01-01        ALT PENEDES        597           03           2
# 2     2018-01-01         ALT URGELL        106           04           1
# 3     2018-01-01              ANOIA        576           06           3
# 4     2018-01-01              BAGES        943           07           6
# ...          ...                ...        ...          ...         ...
# 1939  2022-12-01         TARRAGONES       2275           36           1
# 1940  2022-12-01         TERRA ALTA         40           37           2
# 1941  2022-12-01         VAL D'ARAN         67           39           9
# 1942  2022-12-01  VALLES OCCIDENTAL       6202           40           6
# 1943  2022-12-01    VALLES ORIENTAL       2538           41           3
#
#       PERCENTATGE
# 0        0.368550
# 1        0.335008
# 2        0.943396
# 3        0.520833
# 4        0.636267
# ...           ...
# 1939     0.043956
# 1940     5.000000
# 1941    13.432836
# 1942     0.096743
# 1943     0.118203
#
# [1944 rows x 6 columns]

# %%
aver_perc = data.copy()

aver_perc = pd.DataFrame(aver_perc.groupby(['COMARCA','CODI_COMARCA'])['PERCENTATGE'].apply(np.mean))


aver_perc= aver_perc.reset_index()
aver_perc
# Out:
#               COMARCA CODI_COMARCA  PERCENTATGE
# 0            ALT CAMP           01     0.620432
# 1         ALT EMPORDA           02     0.631884
# 2         ALT PENEDES           03     0.388293
# 3          ALT URGELL           04     3.208121
# 4      ALTA RIBAGORÇA           05    18.386956
# 5               ANOIA           06     0.688381
# 6               BAGES           07     0.622294
# 7           BAIX CAMP           08     0.233152
# 8           BAIX EBRE           09     0.610193
# 9        BAIX EMPORDA           10     0.731625
# 10     BAIX LLOBREGAT           11     0.204943
# 11       BAIX PENEDES           12     0.172564
# 12         BARCELONES           13     0.013068
# 13           BERGUEDA           14     3.820800
# 14           CERDANYA           15     3.843324
# 15   CONCA DE BARBERA           16     1.557550
# 16             GARRAF           17     0.310424
# 17          GARRIGUES           18     1.657783
# 18           GARROTXA           19     1.871220
# 19            GIRONES           20     0.302303
# 20            MARESME           21     0.159435
# 21            MOIANES           42     2.694280
# 22            MONTSIA           22     0.667657
# 23            NOGUERA           23     1.773014
# 24              OSONA           24     0.930618
# 25      PALLARS JUSSA           25     5.223139
# 26     PALLARS SOBIRA           26    14.811656
# 27       PLA D'URGELL           27     0.648129
# 28    PLA DE L'ESTANY           28     0.998444
# 29            PRIORAT           29     4.105550
# 30      RIBERA D'EBRE           30     1.624809
# 31           RIPOLLES           31     5.356351
# 32            SEGARRA           32     1.647518
# 33             SEGRIA           33     0.151115
# 34              SELVA           34     0.533104
# 35           SOLSONES           35     5.150747
# 36         TARRAGONES           36     0.134745
# 37         TERRA ALTA           37     4.373660
# 38             URGELL           38     0.947688
# 39         VAL D'ARAN           39    27.942818
# 40  VALLES OCCIDENTAL           40     0.171366
# 41    VALLES ORIENTAL           41     0.270091

# %% [markdown]
# ## Importing map

# %%
data_dir= '../dades/'
cat = gpd.read_file(data_dir + "divisions-administratives-v2r1-comarques-100000-20220801.shx")
cat.rename(columns = {'NOMCOMAR':'COMARCA'}, inplace = True)
cat.rename(columns = {'CODICOMAR':'CODI_COMARCA'}, inplace = True)
cat.head()
# Out:
#   CODI_COMARCA         COMARCA                CAPCOMAR  AREAC5000  \
# 0           01        Alt Camp                   Valls   537.6317
# 1           02     Alt Empordà                Figueres  1356.6431
# 2           03     Alt Penedès  Vilafranca del Penedès   592.5498
# 3           04      Alt Urgell         la Seu d'Urgell  1447.2028
# 4           05  Alta Ribagorça        el Pont de Suert   427.2234
#
#                                             geometry
# 0  POLYGON ((373635.755 4592021.079, 373669.333 4...
# 1  MULTIPOLYGON (((514495.140 4662167.740, 514492...
# 2  POLYGON ((385914.163 4595999.962, 386085.364 4...
# 3  MULTIPOLYGON (((360736.000 4649167.000, 360624...
# 4  POLYGON ((326572.730 4721574.001, 326622.339 4...

# %% [markdown]
# ## Merging map and data and plotting

# %%
data_merged =pd.merge(cat, aver_perc, on=['CODI_COMARCA'])
data_merged.head()
# Out:
#   CODI_COMARCA       COMARCA_x                CAPCOMAR  AREAC5000  \
# 0           01        Alt Camp                   Valls   537.6317
# 1           02     Alt Empordà                Figueres  1356.6431
# 2           03     Alt Penedès  Vilafranca del Penedès   592.5498
# 3           04      Alt Urgell         la Seu d'Urgell  1447.2028
# 4           05  Alta Ribagorça        el Pont de Suert   427.2234
#
#                                             geometry       COMARCA_y  \
# 0  POLYGON ((373635.755 4592021.079, 373669.333 4...        ALT CAMP
# 1  MULTIPOLYGON (((514495.140 4662167.740, 514492...     ALT EMPORDA
# 2  POLYGON ((385914.163 4595999.962, 386085.364 4...     ALT PENEDES
# 3  MULTIPOLYGON (((360736.000 4649167.000, 360624...      ALT URGELL
# 4  POLYGON ((326572.730 4721574.001, 326622.339 4...  ALTA RIBAGORÇA
#
#    PERCENTATGE
# 0     0.620432
# 1     0.631884
# 2     0.388293
# 3     3.208121
# 4    18.386956

# %%
merged_rescue_tot_gpd= data_merged.copy()



fig, ax = plt.subplots(1,1,figsize=(6,4))
ax.set_xticks([])
ax.set_yticks([])
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('none')
norm = LogNorm()
# plt.rc('text', usetex = True)
# plt.rc('font', family='serif')
plot = merged_rescue_tot_gpd.plot(column = 'PERCENTATGE',
                                  ax=ax,
                                  legend=False,
                                  cmap='Blues',
                                  norm = norm,
                                  legend_kwds={'orientation': "horizontal", 'pad': 0.2})
merged_rescue_tot_gpd.boundary.plot(ax = ax, linewidth = 0.2, color = 'black')
merged_rescue_tot_gpd = merged_rescue_tot_gpd.set_index("COMARCA_x")
#merged_rescue_tot_gpd.loc[list(colors.keys()),:].boundary.plot(ax=ax,color=list(colors.values()), linewidth = 1.5)
merged_rescue_tot_gpd = merged_rescue_tot_gpd.reset_index()
cbar = fig.colorbar(plot.get_children()[0], ax = ax, label = r'perc. rescue actions against nature reported incidents')
cb_ax = fig.axes[1] 
# cb_ax.tick_params(labelsize=10)
plt.savefig('figures/rescats_vs_incidents.pdf')
plt.show()
