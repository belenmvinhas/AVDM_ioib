# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
data_loc = '../dades/'

# %%
trucades_salvament= pd.read_csv(data_loc + 'Dades_d_incidents_operatius_gestionats_pel_CAT112_20231110.csv' )
trucades_filtrades= trucades_salvament[(trucades_salvament["ANY"]<2023) & (trucades_salvament["ANY"]>2017)]

df= trucades_filtrades.sort_values(by="TIPUS",ascending=True)

# show loaded table:
df_meteo = df[trucades_filtrades["TIPUS"] == "Incendi"]
df_meteo
# Out:
# C:\Users\Imma\AppData\Local\Temp\ipykernel_14780\2917701103.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_meteo = df[trucades_filtrades["TIPUS"] == "Incendi"]
#          ANY  MES  PROVINCIA            COMARCA                   MUNICIPI  \
# 196983  2020    4     LLEIDA            NOGUERA                       AGER
# 199834  2020    3  BARCELONA  VALLES OCCIDENTAL           BADIA DEL VALLES
# 310463  2018    2  BARCELONA    VALLES ORIENTAL   SANT ANTONI DE VILAMAJOR
# 197397  2020    4  BARCELONA    VALLES ORIENTAL              LLIÇA D'AMUNT
# 200099  2020    3     LLEIDA             URGELL                 VILAGRASSA
# ...      ...  ...        ...                ...                        ...
# 96805   2022    2     GIRONA        ALT EMPORDA        CASTELLO D'EMPURIES
# 97186   2022    2     GIRONA              SELVA              LLORET DE MAR
# 134828  2021    6  BARCELONA            MARESME  SANT ANDREU DE LLAVANERES
# 73031   2022    7  BARCELONA     BAIX LLOBREGAT   SANTA COLOMA DE CERVELLO
# 52985   2022   12  TARRAGONA       BAIX PENEDES    SANT JAUME DELS DOMENYS
#
#           TIPUS  INCIDENTS
# 196983  Incendi          1
# 199834  Incendi          3
# 310463  Incendi          2
# 197397  Incendi          2
# 200099  Incendi          3
# ...         ...        ...
# 96805   Incendi         10
# 97186   Incendi          8
# 134828  Incendi          8
# 73031   Incendi          3
# 52985   Incendi          1
#
# [29487 rows x 7 columns]

# %%
incendis = df_meteo.copy()
incendis= pd.DataFrame(incendis.groupby(['COMARCA'])['INCIDENTS'].sum()).reset_index()
incendis
# Out:
#               COMARCA  INCIDENTS
# 0            ALT CAMP       2209
# 1         ALT EMPORDA       5162
# 2         ALT PENEDES       3096
# 3          ALT URGELL        735
# 4      ALTA RIBAGORÇA        174
# 5               ANOIA       3094
# 6               BAGES       3663
# 7           BAIX CAMP       6419
# 8           BAIX EBRE       2287
# 9        BAIX EMPORDA       4105
# 10     BAIX LLOBREGAT      13437
# 11       BAIX PENEDES       3707
# 12         BARCELONES      38690
# 13           BERGUEDA        986
# 14           CERDANYA        774
# 15   CONCA DE BARBERA        926
# 16             GARRAF       3773
# 17          GARRIGUES        934
# 18           GARROTXA       1229
# 19            GIRONES       4772
# 20            MARESME       8520
# 21            MOIANES        439
# 22            MONTSIA       1925
# 23            NOGUERA       1295
# 24              OSONA       3209
# 25      PALLARS JUSSA        476
# 26     PALLARS SOBIRA        364
# 27       PLA D'URGELL       1228
# 28    PLA DE L'ESTANY        694
# 29            PRIORAT        503
# 30      RIBERA D'EBRE        795
# 31           RIPOLLES        706
# 32            SEGARRA        701
# 33             SEGRIA       6499
# 34              SELVA       4064
# 35           SOLSONES        360
# 36         TARRAGONES       8229
# 37         TERRA ALTA        531
# 38             URGELL       1075
# 39         VAL D'ARAN        369
# 40  VALLES OCCIDENTAL      18046
# 41    VALLES ORIENTAL       7771

# %%
data_dir= '../dades/'
cat = gpd.read_file(data_dir + "divisions-administratives-v2r1-comarques-100000-20220801.shx")
cat.rename(columns = {'NOMCOMAR':'COMARCA'}, inplace = True)
cat.rename(columns = {'CODICOMAR':'CODI_COMARCA'}, inplace = True)
cat.head()
# Out:
#   CODI_COMARCA         COMARCA                CAPCOMAR  AREAC5000  \
# 0           01        Alt Camp                   Valls   537.6317
# 1           02     Alt Empordà                Figueres  1356.6431
# 2           03     Alt Penedès  Vilafranca del Penedès   592.5498
# 3           04      Alt Urgell         la Seu d'Urgell  1447.2028
# 4           05  Alta Ribagorça        el Pont de Suert   427.2234
#
#                                             geometry
# 0  POLYGON ((373635.755 4592021.079, 373669.333 4...
# 1  MULTIPOLYGON (((514495.140 4662167.740, 514492...
# 2  POLYGON ((385914.163 4595999.962, 386085.364 4...
# 3  MULTIPOLYGON (((360736.000 4649167.000, 360624...
# 4  POLYGON ((326572.730 4721574.001, 326622.339 4...

# %%
mapa=cat.copy()

from unidecode import unidecode
      
def quitar_acentos(cadena):
    # Reemplazar 'ç' por un marcador temporal
    cadena_con_marcador = cadena.replace('ç', '___cedilla___')
    # Aplicar unidecode y luego revertir el marcador temporal
    cadena_sin_acentos = unidecode(cadena_con_marcador).replace('___cedilla___', 'ç')
    
    return cadena_sin_acentos

mapa['COMARCA'] = mapa['COMARCA'].apply(quitar_acentos)

mapa['COMARCA'] = mapa['COMARCA'].str.upper()
mapa.head()
# Out:
#   CODI_COMARCA         COMARCA                CAPCOMAR  AREAC5000  \
# 0           01        ALT CAMP                   Valls   537.6317
# 1           02     ALT EMPORDA                Figueres  1356.6431
# 2           03     ALT PENEDES  Vilafranca del Penedès   592.5498
# 3           04      ALT URGELL         la Seu d'Urgell  1447.2028
# 4           05  ALTA RIBAGORÇA        el Pont de Suert   427.2234
#
#                                             geometry
# 0  POLYGON ((373635.755 4592021.079, 373669.333 4...
# 1  MULTIPOLYGON (((514495.140 4662167.740, 514492...
# 2  POLYGON ((385914.163 4595999.962, 386085.364 4...
# 3  MULTIPOLYGON (((360736.000 4649167.000, 360624...
# 4  POLYGON ((326572.730 4721574.001, 326622.339 4...

# %%
mapa_plot=pd.merge(mapa,incendis,on=['COMARCA'])
mapa_plot
# Out:
#    CODI_COMARCA            COMARCA                 CAPCOMAR  AREAC5000  \
# 0            01           ALT CAMP                    Valls   537.6317
# 1            02        ALT EMPORDA                 Figueres  1356.6431
# 2            03        ALT PENEDES   Vilafranca del Penedès   592.5498
# 3            04         ALT URGELL          la Seu d'Urgell  1447.2028
# 4            05     ALTA RIBAGORÇA         el Pont de Suert   427.2234
# 5            06              ANOIA                 Igualada   867.0471
# 6            07              BAGES                  Manresa  1092.7982
# 7            08          BAIX CAMP                     Reus   696.4883
# 8            09          BAIX EBRE                  Tortosa  1001.9306
# 9            10       BAIX EMPORDA      la Bisbal d'Empordà   701.1353
# 10           11     BAIX LLOBREGAT  Sant Feliu de Llobregat   487.4743
# 11           12       BAIX PENEDES              el Vendrell   296.4311
# 12           13         BARCELONES                Barcelona   146.3935
# 13           14           BERGUEDA                    Berga  1185.2257
# 14           15           CERDANYA                Puigcerdà   546.4545
# 15           16   CONCA DE BARBERA                Montblanc   650.6021
# 16           17             GARRAF     Vilanova i la Geltrú   185.2434
# 17           18          GARRIGUES      les Borges Blanques   797.2156
# 18           19           GARROTXA                     Olot   733.3229
# 19           20            GIRONES                   Girona   575.9353
# 20           21            MARESME                   Mataró   397.9019
# 21           22            MONTSIA                  Amposta   733.6485
# 22           23            NOGUERA                 Balaguer  1783.3727
# 23           24              OSONA                      Vic  1246.9802
# 24           25      PALLARS JUSSA                    Tremp  1343.5020
# 25           26     PALLARS SOBIRA                     Sort  1378.2154
# 26           27       PLA D'URGELL               Mollerussa   305.4285
# 27           28    PLA DE L'ESTANY                 Banyoles   263.3198
# 28           29            PRIORAT                   Falset   498.0777
# 29           30      RIBERA D'EBRE              Móra d'Ebre   827.6182
# 30           31           RIPOLLES                   Ripoll   956.8939
# 31           32            SEGARRA                  Cervera   723.5756
# 32           33             SEGRIA                   Lleida  1396.1161
# 33           34              SELVA  Santa Coloma de Farners   994.0428
# 34           35           SOLSONES                  Solsona  1000.2169
# 35           36         TARRAGONES                Tarragona   320.5849
# 36           37         TERRA ALTA                  Gandesa   742.6641
# 37           38             URGELL                  Tàrrega   578.2949
# 38           39         VAL D'ARAN                   Vielha   632.9978
# 39           40  VALLES OCCIDENTAL      Sabadell / Terrassa   583.0649
# 40           41    VALLES ORIENTAL               Granollers   735.2397
# 41           42            MOIANES                     Moià   337.2896
#
#                                              geometry  INCIDENTS
# 0   POLYGON ((373635.755 4592021.079, 373669.333 4...       2209
# 1   MULTIPOLYGON (((514495.140 4662167.740, 514492...       5162
# 2   POLYGON ((385914.163 4595999.962, 386085.364 4...       3096
# 3   MULTIPOLYGON (((360736.000 4649167.000, 360624...        735
# 4   POLYGON ((326572.730 4721574.001, 326622.339 4...        174
# 5   POLYGON ((370158.839 4628885.052, 370282.509 4...       3094
# 6   POLYGON ((417259.067 4646530.811, 417513.903 4...       3663
# 7   MULTIPOLYGON (((335052.970 4547018.980, 335051...       6419
# 8   MULTIPOLYGON (((311847.200 4514855.880, 311833...       2287
# 9   MULTIPOLYGON (((497966.430 4622427.830, 497965...       4105
# 10  POLYGON ((401068.400 4606276.800, 401178.618 4...      13437
# 11  MULTIPOLYGON (((384508.440 4560878.000, 384505...       3707
# 12  MULTIPOLYGON (((430106.350 4576516.340, 430098...      38690
# 13  MULTIPOLYGON (((391614.800 4661923.500, 391606...        986
# 14  MULTIPOLYGON (((417240.539 4704752.127, 417684...        774
# 15  POLYGON ((369548.800 4603947.800, 370045.800 4...        926
# 16  MULTIPOLYGON (((386888.695 4561204.584, 386881...       3773
# 17  POLYGON ((327888.707 4605730.867, 328155.807 4...        934
# 18  POLYGON ((462306.492 4686925.593, 462315.342 4...       1229
# 19  POLYGON ((494081.526 4662565.750, 494214.686 4...       4772
# 20  POLYGON ((477054.900 4621435.100, 478728.500 4...       8520
# 21  MULTIPOLYGON (((298299.980 4494128.520, 298299...       1925
# 22  POLYGON ((348524.976 4664596.302, 348400.341 4...       1295
# 23  MULTIPOLYGON (((418580.652 4643167.275, 418307...       3209
# 24  MULTIPOLYGON (((317718.105 4693389.714, 317738...        476
# 25  POLYGON ((343217.247 4738499.818, 343225.151 4...        364
# 26  MULTIPOLYGON (((341924.700 4618515.800, 341260...       1228
# 27  POLYGON ((482120.535 4672805.481, 482191.594 4...        694
# 28  POLYGON ((320525.200 4579659.500, 321213.700 4...        503
# 29  POLYGON ((288368.413 4578209.165, 288383.230 4...        795
# 30  MULTIPOLYGON (((419785.996 4664417.149, 419923...        706
# 31  POLYGON ((365993.100 4642951.900, 366072.200 4...        701
# 32  MULTIPOLYGON (((316312.768 4606506.701, 315561...       6499
# 33  MULTIPOLYGON (((482690.024 4613155.364, 482688...       4064
# 34  MULTIPOLYGON (((393371.457 4638570.630, 393374...        360
# 35  MULTIPOLYGON (((363274.620 4554494.750, 363220...       8229
# 36  POLYGON ((280206.273 4568311.294, 280325.826 4...        531
# 37  MULTIPOLYGON (((330423.400 4623950.100, 329861...       1075
# 38  POLYGON ((313407.046 4747612.147, 313430.255 4...        369
# 39  POLYGON ((426549.300 4618464.000, 427202.000 4...      18046
# 40  POLYGON ((449099.721 4628266.206, 449108.947 4...       7771
# 41  POLYGON ((428837.859 4639478.022, 428961.755 4...        439

# %%
#highlight the counties with most rescue actions
merged_rescue_tot_gpd= mapa_plot.copy()



fig, ax = plt.subplots(1,1,figsize=(6,4))
ax.set_xticks([])
ax.set_yticks([])
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('none')
norm = LogNorm()
# plt.rc('text', usetex = True)
# plt.rc('font', family='serif')
plot = merged_rescue_tot_gpd.plot(column = 'INCIDENTS',
                                  ax=ax,
                                  legend=False,
                                  cmap='Blues',
                                  norm = norm,
                                  legend_kwds={'orientation': "horizontal", 'pad': 0.2})
merged_rescue_tot_gpd.boundary.plot(ax = ax, linewidth = 0.2, color = 'black')
merged_rescue_tot_gpd = merged_rescue_tot_gpd.set_index("COMARCA")
#merged_rescue_tot_gpd.loc[list(colors.keys()),:].boundary.plot(ax=ax,color=list(colors.values()), linewidth = 1.5)
merged_rescue_tot_gpd = merged_rescue_tot_gpd.reset_index()
cbar = fig.colorbar(plot.get_children()[0], ax = ax, label = r'num. rescue actions 2018-2022')
cb_ax = fig.axes[1] 
# cb_ax.tick_params(labelsize=10)
#plt.savefig('figures/total_num_2018_2022.pdf')
plt.show()
