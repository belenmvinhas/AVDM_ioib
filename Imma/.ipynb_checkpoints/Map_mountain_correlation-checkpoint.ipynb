# %% [markdown]
# # Plotting percentatge of mountain incidents acted by the fire departement

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing correlated incidents with fire departement actions

# %%
direct = 'csv_files/'

df = pd.read_csv(direct + 'Correlations_mountain.csv')
df['CODI_COMARCA'] = df['CODI_COMARCA'].astype(str).str.zfill(2)
df
# Out:
#          ANY-MES            COMARCA  INCIDENTS CODI_COMARCA  SALVAMENTS
# 0     2018-01-01        ALT EMPORDA        821           02           2
# 1     2018-01-01        ALT PENEDES        605           03           2
# 2     2018-01-01              ANOIA        582           06           3
# 3     2018-01-01              BAGES        945           07           6
# 4     2018-01-01       BAIX EMPORDA        636           10           2
# ...          ...                ...        ...          ...         ...
# 1864  2022-12-01         TARRAGONES       2293           36           1
# 1865  2022-12-01         TERRA ALTA         40           37           2
# 1866  2022-12-01         VAL D'ARAN         67           39           9
# 1867  2022-12-01  VALLES OCCIDENTAL       6226           40           5
# 1868  2022-12-01    VALLES ORIENTAL       2555           41           3
#
# [1869 rows x 5 columns]

# %%
def percentatge(x,y):
    p = x/y*100
    return p

data=df.copy()

data['PERCENTATGE'] = data.apply(lambda row: percentatge(row['SALVAMENTS'], row['INCIDENTS']), axis=1)

data

# results= data[data['COMARCA']=='BERGUEDA']
# results
# Out:
#          ANY-MES            COMARCA  INCIDENTS CODI_COMARCA  SALVAMENTS  \
# 0     2018-01-01        ALT EMPORDA        821           02           2
# 1     2018-01-01        ALT PENEDES        605           03           2
# 2     2018-01-01              ANOIA        582           06           3
# 3     2018-01-01              BAGES        945           07           6
# 4     2018-01-01       BAIX EMPORDA        636           10           2
# ...          ...                ...        ...          ...         ...
# 1864  2022-12-01         TARRAGONES       2293           36           1
# 1865  2022-12-01         TERRA ALTA         40           37           2
# 1866  2022-12-01         VAL D'ARAN         67           39           9
# 1867  2022-12-01  VALLES OCCIDENTAL       6226           40           5
# 1868  2022-12-01    VALLES ORIENTAL       2555           41           3
#
#       PERCENTATGE
# 0        0.243605
# 1        0.330579
# 2        0.515464
# 3        0.634921
# 4        0.314465
# ...           ...
# 1864     0.043611
# 1865     5.000000
# 1866    13.432836
# 1867     0.080308
# 1868     0.117417
#
# [1869 rows x 6 columns]

# %%
aver_perc = data.copy()

aver_perc = pd.DataFrame(aver_perc.groupby(['COMARCA','CODI_COMARCA'])['PERCENTATGE'].apply(np.mean))


aver_perc= aver_perc.reset_index()
aver_perc
# Out:
#               COMARCA CODI_COMARCA  PERCENTATGE
# 0            ALT CAMP           01     0.590444
# 1         ALT EMPORDA           02     0.466397
# 2         ALT PENEDES           03     0.370550
# 3          ALT URGELL           04     3.104360
# 4      ALTA RIBAGORÇA           05    17.141564
# 5               ANOIA           06     0.669160
# 6               BAGES           07     0.593721
# 7           BAIX CAMP           08     0.206668
# 8           BAIX EBRE           09     0.485939
# 9        BAIX EMPORDA           10     0.568833
# 10     BAIX LLOBREGAT           11     0.183801
# 11       BAIX PENEDES           12     0.155203
# 12         BARCELONES           13     0.012160
# 13           BERGUEDA           14     3.649865
# 14           CERDANYA           15     3.676059
# 15   CONCA DE BARBERA           16     1.459088
# 16             GARRAF           17     0.212646
# 17          GARRIGUES           18     1.627850
# 18           GARROTXA           19     1.812272
# 19            GIRONES           20     0.267972
# 20            MARESME           21     0.127618
# 21            MOIANES           42     2.556126
# 22            MONTSIA           22     0.478277
# 23            NOGUERA           23     1.572904
# 24              OSONA           24     0.868932
# 25      PALLARS JUSSA           25     4.803234
# 26     PALLARS SOBIRA           26    13.149700
# 27       PLA D'URGELL           27     0.639950
# 28    PLA DE L'ESTANY           28     0.907526
# 29            PRIORAT           29     3.976568
# 30      RIBERA D'EBRE           30     1.482589
# 31           RIPOLLES           31     5.061917
# 32            SEGARRA           32     1.600683
# 33             SEGRIA           33     0.125599
# 34              SELVA           34     0.427365
# 35           SOLSONES           35     4.828568
# 36         TARRAGONES           36     0.090439
# 37         TERRA ALTA           37     4.110136
# 38             URGELL           38     0.990903
# 39         VAL D'ARAN           39    25.841513
# 40  VALLES OCCIDENTAL           40     0.165760
# 41    VALLES ORIENTAL           41     0.262090

# %% [markdown]
# ## Importing map

# %%
data_dir= '../dades/'
cat = gpd.read_file(data_dir + "divisions-administratives-v2r1-comarques-100000-20220801.shx")
cat.rename(columns = {'NOMCOMAR':'COMARCA'}, inplace = True)
cat.rename(columns = {'CODICOMAR':'CODI_COMARCA'}, inplace = True)
cat
# Out:
#    CODI_COMARCA            COMARCA                 CAPCOMAR  AREAC5000  \
# 0            01           Alt Camp                    Valls   537.6317
# 1            02        Alt Empordà                 Figueres  1356.6431
# 2            03        Alt Penedès   Vilafranca del Penedès   592.5498
# 3            04         Alt Urgell          la Seu d'Urgell  1447.2028
# 4            05     Alta Ribagorça         el Pont de Suert   427.2234
# 5            06              Anoia                 Igualada   867.0471
# 6            07              Bages                  Manresa  1092.7982
# 7            08          Baix Camp                     Reus   696.4883
# 8            09          Baix Ebre                  Tortosa  1001.9306
# 9            10       Baix Empordà      la Bisbal d'Empordà   701.1353
# 10           11     Baix Llobregat  Sant Feliu de Llobregat   487.4743
# 11           12       Baix Penedès              el Vendrell   296.4311
# 12           13         Barcelonès                Barcelona   146.3935
# 13           14           Berguedà                    Berga  1185.2257
# 14           15           Cerdanya                Puigcerdà   546.4545
# 15           16   Conca de Barberà                Montblanc   650.6021
# 16           17             Garraf     Vilanova i la Geltrú   185.2434
# 17           18          Garrigues      les Borges Blanques   797.2156
# 18           19           Garrotxa                     Olot   733.3229
# 19           20            Gironès                   Girona   575.9353
# 20           21            Maresme                   Mataró   397.9019
# 21           22            Montsià                  Amposta   733.6485
# 22           23            Noguera                 Balaguer  1783.3727
# 23           24              Osona                      Vic  1246.9802
# 30  MULTIPOLYGON (((419785.996 4664417.149, 419923...
# 31  POLYGON ((365993.100 4642951.900, 366072.200 4...
# 32  MULTIPOLYGON (((316312.768 4606506.701, 315561...
# 33  MULTIPOLYGON (((482690.024 4613155.364, 482688...
# 34  MULTIPOLYGON (((393371.457 4638570.630, 393374...
# 35  MULTIPOLYGON (((363274.620 4554494.750, 363220...
# 36  POLYGON ((280206.273 4568311.294, 280325.826 4...
# 37  MULTIPOLYGON (((330423.400 4623950.100, 329861...
# 38  POLYGON ((313407.046 4747612.147, 313430.255 4...
# 39  POLYGON ((426549.300 4618464.000, 427202.000 4...
# 40  POLYGON ((449099.721 4628266.206, 449108.947 4...
# 41  POLYGON ((428837.859 4639478.022, 428961.755 4...

# %% [markdown]
# ## Merging map and data and plotting

# %%
data_merged =pd.merge(cat, aver_perc, on=['CODI_COMARCA'])
data_merged.head()
# Out:
#   CODI_COMARCA       COMARCA_x                CAPCOMAR  AREAC5000  \
# 0           01        Alt Camp                   Valls   537.6317
# 1           02     Alt Empordà                Figueres  1356.6431
# 2           03     Alt Penedès  Vilafranca del Penedès   592.5498
# 3           04      Alt Urgell         la Seu d'Urgell  1447.2028
# 4           05  Alta Ribagorça        el Pont de Suert   427.2234
#
#                                             geometry       COMARCA_y  \
# 0  POLYGON ((373635.755 4592021.079, 373669.333 4...        ALT CAMP
# 1  MULTIPOLYGON (((514495.140 4662167.740, 514492...     ALT EMPORDA
# 2  POLYGON ((385914.163 4595999.962, 386085.364 4...     ALT PENEDES
# 3  MULTIPOLYGON (((360736.000 4649167.000, 360624...      ALT URGELL
# 4  POLYGON ((326572.730 4721574.001, 326622.339 4...  ALTA RIBAGORÇA
#
#    PERCENTATGE
# 0     0.590444
# 1     0.466397
# 2     0.370550
# 3     3.104360
# 4    17.141564

# %%
#highlight the counties with most rescue actions
# colors = {"Baix Llobregat":'darkorange',
#           "Vallès Occidental":'cornflowerblue',
#           "Val d'Aran":'mediumorchid',
#           "Ripollès":'royalblue',
#           "Berguedà":'darkred'}

fig, ax = plt.subplots(1,1,figsize=(7,7))
ax.set_xticks([])
ax.set_yticks([])
plt.rc('text', usetex = True)
plt.rc('font', family='serif')
data_merged.plot(column = 'PERCENTATGE',
                                  ax=ax,
                                  legend=True,
                                  cmap='viridis',
                                  legend_kwds={'orientation': "horizontal", 'pad': 0.02})
merged_rescue_tot_gpd = data_merged.set_index("COMARCA_x")
#merged_rescue_tot_gpd.loc[list(colors.keys()),:].boundary.plot(ax=ax,color=list(colors.values()))
merged_rescue_tot_gpd = merged_rescue_tot_gpd.reset_index()
cb_ax = fig.axes[1] 
cb_ax.tick_params(labelsize=15)
ax.set_title(r'Percentage of fire department actions with respect to total emergency incidents of mountain nature between 2018 and 2022', fontsize = 9)
plt.savefig('figures/fire_over_incident.pdf')
plt.show()
