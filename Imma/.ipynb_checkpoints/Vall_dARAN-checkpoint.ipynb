# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
direc = '../dades/'

# %%
incidents_salvament= pd.read_csv(direc + 'Dades_d_incidents_operatius_gestionats_pel_CAT112_20231110.csv' )
incidents_salvament= incidents_salvament[(incidents_salvament["ANY"]<=2022) & (incidents_salvament["ANY"]>=2018)]


incidents_salvament.head()
# Out:
#         ANY  MES  PROVINCIA           COMARCA                 MUNICIPI  \
# 50181  2022   12  TARRAGONA  CONCA DE BARBERA  SANTA COLOMA DE QUERALT
# 50182  2022   12     LLEIDA      PLA D'URGELL       BELL-LLOC D'URGELL
# 50183  2022   12     GIRONA             SELVA                     OSOR
# 50184  2022   12  BARCELONA   VALLES ORIENTAL    SANT FELIU DE CODINES
# 50185  2022   12     GIRONA          CERDANYA        GUILS DE CERDANYA
#
#                        TIPUS  INCIDENTS
# 50181                Incendi          1
# 50182                Incendi          1
# 50183     Altres incidències          1
# 50184                Incendi          1
# 50185  Assistència sanitària          2

# %%
grouped_df=incidents_salvament.copy()

grouped_df=pd.DataFrame(grouped_df.groupby(['COMARCA','TIPUS'])['INCIDENTS'].mean()).reset_index()

grouped_df['COMARCA'].unique()
# Out:
# array(['ALT CAMP', 'ALT EMPORDA', 'ALT PENEDES', 'ALT URGELL',
#        'ALTA RIBAGORÇA', 'ANOIA', 'BAGES', 'BAIX CAMP', 'BAIX EBRE',
#        'BAIX EMPORDA', 'BAIX LLOBREGAT', 'BAIX PENEDES', 'BARCELONES',
#        'BERGUEDA', 'CERDANYA', 'CONCA DE BARBERA', 'GARRAF', 'GARRIGUES',
#        'GARROTXA', 'GIRONES', 'MARESME', 'MOIANES', 'MONTSIA', 'NOGUERA',
#        'OSONA', 'PALLARS JUSSA', 'PALLARS SOBIRA', "PLA D'URGELL",
#        "PLA DE L'ESTANY", 'PRIORAT', "RIBERA D'EBRE", 'RIPOLLES',
#        'SEGARRA', 'SEGRIA', 'SELVA', 'SOLSONES', 'TARRAGONES',
#        'TERRA ALTA', 'URGELL', "VAL D'ARAN", 'VALLES OCCIDENTAL',
#        'VALLES ORIENTAL'], dtype=object)

# %%
new_order = [0,5,7,2,1,3,4,6,8,9]
noguera = grouped_df[grouped_df['COMARCA']== 'NOGUERA'].iloc[new_order].reset_index(drop=True)
osona = grouped_df[grouped_df['COMARCA']== 'OSONA'].iloc[new_order].reset_index(drop=True)
pallars_jussa = grouped_df[grouped_df['COMARCA']== 'PALLARS JUSSA'].iloc[new_order].reset_index(drop=True)
pallars_sobira = grouped_df[grouped_df['COMARCA']== 'PALLARS SOBIRA'].iloc[new_order].reset_index(drop=True)
pla_durgell = grouped_df[grouped_df['COMARCA']== "PLA D'URGELL"].iloc[new_order].reset_index(drop=True)

pla_de_lestany = grouped_df[grouped_df['COMARCA']== "PLA DE L'ESTANY"].iloc[new_order].reset_index(drop=True)
priorat = grouped_df[grouped_df['COMARCA']== 'PRIORAT'].iloc[new_order].reset_index(drop=True)
ribera_debre = grouped_df[grouped_df['COMARCA']== "RIBERA D'EBRE"].iloc[new_order].reset_index(drop=True)
ripolles = grouped_df[grouped_df['COMARCA']== 'RIPOLLES'].iloc[new_order].reset_index(drop=True)
segarra = grouped_df[grouped_df['COMARCA']== 'SEGARRA'].iloc[new_order].reset_index(drop=True)
segria = grouped_df[grouped_df['COMARCA']== 'SEGRIA'].iloc[new_order].reset_index(drop=True)
selva = grouped_df[grouped_df['COMARCA']== 'SELVA'].iloc[new_order].reset_index(drop=True)
solsones = grouped_df[grouped_df['COMARCA']== 'SOLSONES'].iloc[new_order].reset_index(drop=True)
tarragones = grouped_df[grouped_df['COMARCA']== 'TARRAGONES'].iloc[new_order].reset_index(drop=True)
terra_alta = grouped_df[grouped_df['COMARCA']== 'TERRA ALTA'].iloc[new_order].reset_index(drop=True)
urgell = grouped_df[grouped_df['COMARCA']== 'URGELL'].iloc[new_order].reset_index(drop=True)
val_daran = grouped_df[grouped_df['COMARCA']== "VAL D'ARAN"].iloc[new_order].reset_index(drop=True)
valles_occidental = grouped_df[grouped_df['COMARCA']== 'VALLES OCCIDENTAL'].iloc[new_order].reset_index(drop=True)
valles_oriental = grouped_df[grouped_df['COMARCA']== 'VALLES ORIENTAL'].iloc[new_order].reset_index(drop=True)
alt_camp = grouped_df[grouped_df['COMARCA']== 'ALT CAMP'].iloc[new_order].reset_index(drop=True)
alt_emporda = grouped_df[grouped_df['COMARCA']== 'ALT EMPORDA'].iloc[new_order].reset_index(drop=True)
alt_penedes = grouped_df[grouped_df['COMARCA']== 'ALT PENEDES'].iloc[new_order].reset_index(drop=True)
alt_urgell = grouped_df[grouped_df['COMARCA']== 'ALT URGELL'].iloc[new_order].reset_index(drop=True)
alta_ribagorca = grouped_df[grouped_df['COMARCA']== 'ALTA RIBAGORÇA'].iloc[new_order].reset_index(drop=True)
anoia = grouped_df[grouped_df['COMARCA']== 'ANOIA'].iloc[new_order].reset_index(drop=True)
bages = grouped_df[grouped_df['COMARCA']== 'BAGES'].iloc[new_order].reset_index(drop=True)
baix_camp = grouped_df[grouped_df['COMARCA']== 'BAIX CAMP'].iloc[new_order].reset_index(drop=True)
baix_ebre = grouped_df[grouped_df['COMARCA']== 'BAIX EBRE'].iloc[new_order].reset_index(drop=True)
baix_emporda = grouped_df[grouped_df['COMARCA']== 'BAIX EMPORDA'].iloc[new_order].reset_index(drop=True)
baix_llobregat = grouped_df[grouped_df['COMARCA']== 'BAIX LLOBREGAT'].iloc[new_order].reset_index(drop=True)
baix_penedes = grouped_df[grouped_df['COMARCA']== 'BAIX PENEDES'].iloc[new_order].reset_index(drop=True)
barcelones = grouped_df[grouped_df['COMARCA']== 'BARCELONES'].iloc[new_order].reset_index(drop=True)
bergueda = grouped_df[grouped_df['COMARCA']== 'BERGUEDA'].iloc[new_order].reset_index(drop=True)
cerdanya = grouped_df[grouped_df['COMARCA']== 'CERDANYA'].iloc[new_order].reset_index(drop=True)
conca = grouped_df[grouped_df['COMARCA']== 'CONCA DE BARBERA'].iloc[new_order].reset_index(drop=True)
garraf = grouped_df[grouped_df['COMARCA']== 'GARRAF'].iloc[new_order].reset_index(drop=True)
garrigues = grouped_df[grouped_df['COMARCA']== 'GARRIGUES'].iloc[new_order].reset_index(drop=True)
garrotxa = grouped_df[grouped_df['COMARCA']== 'GARROTXA'].iloc[new_order].reset_index(drop=True)
girones = grouped_df[grouped_df['COMARCA']== 'GIRONES'].iloc[new_order].reset_index(drop=True)
maresme = grouped_df[grouped_df['COMARCA']== 'MARESME'].iloc[new_order].reset_index(drop=True)
moianes = grouped_df[grouped_df['COMARCA']== 'MOIANES'].iloc[new_order].reset_index(drop=True)
montsia = grouped_df[grouped_df['COMARCA']== 'MONTSIA'].iloc[new_order].reset_index(drop=True)

montsia
# Out:
#    COMARCA                       TIPUS  INCIDENTS
# 0  MONTSIA                    Accident   2.123596
# 1  MONTSIA                     Incendi   3.745136
# 2  MONTSIA                Meteorologia   6.915094
# 3  MONTSIA       Assistència sanitària  26.638681
# 4  MONTSIA          Altres incidències   4.650655
# 5  MONTSIA                     Civisme   3.986911
# 6  MONTSIA  Fuita (aigua, gas, altres)   1.465517
# 7  MONTSIA                Medi ambient   2.030651
# 8  MONTSIA                   Seguretat  16.730600
# 9  MONTSIA                     Trànsit  10.381410

# %%
f2 = plt.figure(figsize=(15, 15))
ax1 = plt.subplot2grid((3, 2), (0, 0), colspan=1)
ax2 = plt.subplot2grid((3, 2), (0, 1), colspan=1)
ax3 = plt.subplot2grid((3, 2), (1, 0), colspan=2)
ax4 = plt.subplot2grid((3, 2), (2, 0), colspan=2)
plt.tight_layout()



fig, axes = plt.subplots(1, 5, figsize=(12, 6))  # Adjust the figure size as needed
pie1 = axes[0].pie(noguera['INCIDENTS'], explode= explode, autopct='%1.1f%%', pctdistance=1.1, startangle=20, shadow=False)
plt.legend(pie1[0], noguera['TIPUS'], bbox_to_anchor=(1, 0.5), loc="best", fontsize=8 )
axes[0].set_title("Noguera")

pie2= axes[1].pie(accions_BARCEL['INCIDENTS'], explode= explode, autopct=lambda p: '{:.1f}%'.format(p) if p > 1 else '', pctdistance=1.1, startangle=20, shadow=False)
plt.legend(pie2[0], accions_BARCEL['TIPUS'], bbox_to_anchor=(1, 0.5), loc="best", fontsize=8 )
axes[1].set_title('Barcelonès')



# Adjust layout to prevent overlap
plt.savefig('./figures/comparation_incidents.pdf')
plt.tight_layout()

# Show the plot
plt.show()

# %%
explode = (0.1, 0.1, 0.1, 0.1, 0,0,0,0,0,0)

fig, axes = plt.subplots(1,2, figsize=(12, 6))  # Adjust the figure size as needed
pie1 = axes[0].pie(val_daran['INCIDENTS'], explode= explode, autopct='%1.1f%%', pctdistance=1.1, startangle=20, shadow=False)
plt.legend(pie1[0], val_daran['TIPUS'], bbox_to_anchor=(1, 0.5), loc="best", fontsize=12 )
axes[0].set_title("Vall d'Aran")

# Plot the second pie chart
pie2= axes[1].pie(accions_BARCEL['INCIDENTS'], explode= explode, autopct=lambda p: '{:.1f}%'.format(p) if p > 1 else '', pctdistance=1.1, startangle=20, shadow=False)
plt.legend(pie2[0], accions_BARCEL['TIPUS'], bbox_to_anchor=(1, 0.5), loc="best", fontsize=12 )
axes[1].set_title('Barcelonès')


fig, axes = plt.subplots(4,10, figsize=(12, 6))

pie3 = axes[0,0].pie(noguera['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[0,0].set_title("Noguera")

pie4 = axes[0,1].pie(osona['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[0,1].set_title("Osona")

pie1 = axes[0,2].pie(pallars_jussa['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[0,2].set_title("Pallars Jussà")

pie1 = axes[0,3].pie(pallars_sobira['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[0,3].set_title("Pallars Sobirà")

pie1 = axes[0,4].pie(pla_durgell['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[0,4].set_title("Pla d'Urgell")
pie1 = axes[0,5].pie(pla_de_lestany ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[0,5].set_title("Pla De L'Estany")
pie1 = axes[0,6].pie(priorat ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[0,6].set_title("Priorat")
pie1 = axes[0,7].pie(ribera_debre ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[0,7].set_title("Ribera D'Ebre")
pie1 = axes[0,8].pie(ripolles ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[0,8].set_title("Ripollès")
pie1 = axes[0,9].pie(segarra ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[0,9].set_title("Segarra")
pie1 = axes[1,0].pie(segria ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[1,0].set_title("Segrià")
pie1 = axes[1,1].pie(selva ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[1,1].set_title("Selva")
pie1 = axes[1,2].pie(solsones ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[1,2].set_title("Solsonès")
pie1 = axes[1,3].pie(tarragones ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[1,3].set_title("Tarragonès")
pie1 = axes[1,4].pie(terra_alta ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[1,4].set_title("Terra Alta")
pie1 = axes[1,5].pie(urgell ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[1,5].set_title("Urgell")
pie1 = axes[1,6].pie(montsia ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[1,6].set_title("Montsià")
pie1 = axes[1,7].pie(valles_occidental ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[1,7].set_title("V. Occidental")
pie1 = axes[1,8].pie(valles_oriental ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[1,8].set_title("V. Oriental")
pie1 = axes[1,9].pie(alt_camp ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[1,9].set_title("Alt Camp")

pie1 = axes[2,0].pie(alt_emporda ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[2,0].set_title("Alt Empordà")
pie1 = axes[2,1].pie(alt_penedes ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[2,1].set_title("Alt Penedés")
pie1 = axes[2,2].pie(alt_urgell ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[2,2].set_title("Alt Urgell")
pie1 = axes[2,3].pie(alta_ribagorca ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[2,3].set_title("Alta Ribagorça")
pie1 = axes[2,4].pie(anoia ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[2,4].set_title("Anoia")
pie1 = axes[2,5].pie(bages ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[2,5].set_title("Bages")
pie1 = axes[2,6].pie(baix_camp ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[2,6].set_title("Baix Camp")
pie1 = axes[2,7].pie(baix_ebre ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[2,7].set_title("Baix Ebre")
pie1 = axes[2,8].pie(baix_emporda ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[2,8].set_title("Baix Emporda")
pie1 = axes[2,9].pie(baix_llobregat ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[2,9].set_title("Baix Llobregat")

pie1 = axes[3,0].pie(baix_penedes ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[3,0].set_title("Baix Penedès")
pie1 = axes[3,1].pie(moianes ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[3,1].set_title("Moianès")
pie1 = axes[3,2].pie(bergueda ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[3,2].set_title("Berguedè")
pie1 = axes[3,3].pie(cerdanya ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[3,3].set_title("Cerdanya")
pie1 = axes[3,4].pie(conca ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[3,4].set_title("Conca De Barbera")
pie1 = axes[3,5].pie(garraf ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[3,5].set_title("Garraf")
pie1 = axes[3,6].pie(garrigues ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[3,6].set_title("Garrigues")
pie1 = axes[3,7].pie(garrotxa ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[3,7].set_title("Garrotxa")
pie1 = axes[3,8].pie(girones ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[3,8].set_title("Gironès")
pie1 = axes[3,9].pie(maresme ['INCIDENTS'], explode= explode, startangle=20, shadow=False)
axes[3,9].set_title("Maresme")



#plt.savefig('./figures/comparation_incidents.pdf')
plt.tight_layout()
plt.savefig('./figures/comparison.png')
# Show the plot
plt.show()

# %%
explode = (0.1, 0.1, 0.1, 0.1, 0,0,0,0,0,0)

# Crear la figura y la cuadrícula de subgráficos
fig, axes = plt.subplots(5, 8, figsize=(20, 10))

# Configurar los subgráficos grandes en la primera fila
axes[0, 0].set_title('Subplot 1 (Grande)')
axes[0, 1].set_title('Subplot 2 (Grande)')

# Configurar los subgráficos pequeños en las filas restantes
for i in range(2, 42):
    row = (i - 2) // 10 + 1  # Calcular la fila actual (comenzando desde 1)
    col = (i - 2) % 10       # Calcular la columna actual

    axes[row, col].set_title(f'Subplot {i}')

    # Agregar contenido a los subgráficos pequeños (por ejemplo, datos aleatorios)
    axes[row, col].plt.pie(accions_VA['INCIDENTS'], autopct='%1.1f%%', explode=explode, startangle=10)
    plt.legend(pie[0], accions_VA['TIPUS'], bbox_to_anchor=(1, 0.5), loc="best", fontsize=8 )

# Ajustar el diseño
plt.tight_layout()

# Mostrar la figura
plt.show()




plt.figure(figsize=(8, 8))
pie = plt.pie(accions_VA['INCIDENTS'], autopct='%1.1f%%', explode=explode, startangle=10)
plt.legend(pie[0], accions_VA['TIPUS'], bbox_to_anchor=(1, 0.5), loc="best", fontsize=8 )
plt.title('Diagrama de Sectors')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-76-ec80786d0f83> in <module>
#      11     col = (i - 2) % 10       # Calcular la columna actual
#      12
# ---> 13     axes[row, col].set_title(f'Subplot {i}')
#      14
#      15
#
# IndexError: index 8 is out of bounds for axis 1 with size 8

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np

# Crear la figura y especificar la cuadrícula
fig = plt.figure(figsize=(12, 8))
gs = gridspec.GridSpec(2, 6, width_ratios=[2, 2, 1, 1, 1, 1], height_ratios=[1, 1])

# Subgráficos grandes en la primera fila
ax1 = plt.subplot(gs[0, 0:2])
ax1.set_title('Subplot 1 (Grande)')

ax2 = plt.subplot(gs[0, 2:4])
ax2.set_title('Subplot 2 (Grande)')

# Subgráficos pequeños en la segunda fila
for i in range(2, 42):
    ax = plt.subplot(gs[1, i-2])
    ax.set_title(f'Subplot {i}')

    # Agregar contenido a los subgráficos pequeños (por ejemplo, datos aleatorios)
    x = np.linspace(0, 1, 100)
    y = np.random.rand(100)
    ax.plot(x, y)

# Ajustar el diseño
plt.tight_layout()

# Mostrar la figura
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-67-0a31acf2cb50> in <module>
#      16 # Subgráficos pequeños en la segunda fila
#      17 for i in range(2, 42):
# ---> 18     ax = plt.subplot(gs[1, i-2])
#      19     ax.set_title(f'Subplot {i}')
#      20
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\gridspec.py in __getitem__(self, key)
#     235                 raise ValueError("Unrecognized subplot spec") from err
#     236             num1, num2 = np.ravel_multi_index(
# --> 237                 [_normalize(k1, nrows, 0), _normalize(k2, ncols, 1)],
#     238                 (nrows, ncols))
#     239         else:  # Single key
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\gridspec.py in _normalize(key, size, axis)
#     223                     return key, key
#     224                 elif axis is not None:
# ...

# %%
accions_VA =incidents_salvament.copy()
# VA_2018 = accions_VA[accions_VA['ANY']==2018]
# VA_2019 = accions_VA[accions_VA['ANY']==2019]
# VA_2020 = accions_VA[accions_VA['ANY']==2020]
# VA_2021 = accions_VA[accions_VA['ANY']==2021]
# VA_2022 = accions_VA[accions_VA['ANY']==2022]

VA_2018= pd.DataFrame(accions_VA.groupby(['TIPUS'])['INCIDENTS'].mean()).reset_index()
# VA_2019 = pd.DataFrame(VA_2019.groupby(['TIPUS'])['INCIDENTS'].sum()).reset_index()
# VA_2020 =pd.DataFrame(VA_2020.groupby(['TIPUS'])['INCIDENTS'].sum()).reset_index()
# VA_2021 = pd.DataFrame(VA_2021.groupby(['TIPUS'])['INCIDENTS'].sum()).reset_index()
# VA_2022 = pd.DataFrame(VA_2022.groupby(['TIPUS'])['INCIDENTS'].sum()).reset_index()

VA_2018
# Out:
#                         TIPUS  INCIDENTS
# 0                    Accident   2.938596
# 1          Altres incidències   3.259067
# 2       Assistència sanitària   4.290984
# 3                     Civisme   5.033520
# 4  Fuita (aigua, gas, altres)   1.225806
# 5                     Incendi   2.236364
# 6                Medi ambient   1.470588
# 7                Meteorologia   1.473684
# 8                   Seguretat   6.813953
# 9                     Trànsit   7.383721

# %%
accions_VA=VA_2018.copy()
new_order = [0,5,7,2,1,3,4,6,8,9]  # Specify the new order of rows
accions_VA = accions_VA.iloc[new_order].reset_index(drop=True)
explode = (0.1, 0.1, 0.1, 0.1, 0,0,0,0,0,0)

plt.figure(figsize=(8, 8))
pie = plt.pie(accions_VA['INCIDENTS'], autopct='%1.1f%%', explode=explode, startangle=10)
plt.legend(pie[0], accions_VA['TIPUS'], bbox_to_anchor=(1, 0.5), loc="best", fontsize=8 )
plt.title('Diagrama de Sectors')
plt.show()
#labels=VA_2018['TIPUS']

accions_VA
# Out:
#                         TIPUS  INCIDENTS
# 0                    Accident   2.938596
# 1                     Incendi   2.236364
# 2                Meteorologia   1.473684
# 3       Assistència sanitària   4.290984
# 4          Altres incidències   3.259067
# 5                     Civisme   5.033520
# 6  Fuita (aigua, gas, altres)   1.225806
# 7                Medi ambient   1.470588
# 8                   Seguretat   6.813953
# 9                     Trànsit   7.383721

# %%
incidents_salvament= pd.read_csv(direc + 'Dades_d_incidents_operatius_gestionats_pel_CAT112_20231110.csv' )
incidents_salvament= incidents_salvament[(incidents_salvament["ANY"]<=2022) & (incidents_salvament["ANY"]>=2018)]

incidents_BAR= incidents_salvament[(incidents_salvament['COMARCA']=="BARCELONES")]
incidents_BAR.head()
# Out:
#         ANY  MES  PROVINCIA     COMARCA                   MUNICIPI  \
# 50318  2022   12  BARCELONA  BARCELONES  L'HOSPITALET DE LLOBREGAT
# 50446  2022   12  BARCELONA  BARCELONES                  BARCELONA
# 50506  2022   12  BARCELONA  BARCELONES        SANT ADRIA DE BESOS
# 50980  2022   12  BARCELONA  BARCELONES        SANT ADRIA DE BESOS
# 50984  2022   12  BARCELONA  BARCELONES                  BARCELONA
#
#                             TIPUS  INCIDENTS
# 50318                     Incendi         69
# 50446                Medi ambient         32
# 50506          Altres incidències         44
# 50980  Fuita (aigua, gas, altres)          1
# 50984                     Incendi        588

# %%
accions_BA =incidents_BAR.copy()
# VA_2018 = accions_VA[accions_VA['ANY']==2018]
# VA_2019 = accions_VA[accions_VA['ANY']==2019]
# VA_2020 = accions_VA[accions_VA['ANY']==2020]
# VA_2021 = accions_VA[accions_VA['ANY']==2021]
# VA_2022 = accions_VA[accions_VA['ANY']==2022]

accions_BA= pd.DataFrame(accions_BA.groupby(['TIPUS'])['INCIDENTS'].mean()).reset_index()
accions_BA
# Out:
#                         TIPUS    INCIDENTS
# 0                    Accident    36.963211
# 1          Altres incidències   506.226667
# 2       Assistència sanitària  2898.176667
# 3                     Civisme  1418.753333
# 4  Fuita (aigua, gas, altres)    58.184564
# 5                     Incendi   128.966667
# 6                Medi ambient    15.114815
# 7                Meteorologia    36.712264
# 8                   Seguretat  3756.970000
# 9                     Trànsit   903.576667

# %%
BAR=accions_BA.copy()
new_order = [0,5,7,2,1,3,4,6,8,9] # Specify the new order of rows
BAR = BAR.iloc[new_order].reset_index(drop=True)
explode = (0.1, 0.1, 0.1, 0.1, 0,0,0,0,0,0)

plt.figure(figsize=(8, 8))
pie= plt.pie(BAR['INCIDENTS'], autopct='%1.1f%%', explode=explode, startangle=10)
plt.legend(pie[0], BAR['TIPUS'], bbox_to_anchor=(1, 0.5), loc="best", fontsize=8 )
plt.title('Diagrama de Sectors')
plt.show()


BAR
# Out:
#                         TIPUS    INCIDENTS
# 0                    Accident    36.963211
# 1                     Incendi   128.966667
# 2                Meteorologia    36.712264
# 3       Assistència sanitària  2898.176667
# 4          Altres incidències   506.226667
# 5                     Civisme  1418.753333
# 6  Fuita (aigua, gas, altres)    58.184564
# 7                Medi ambient    15.114815
# 8                   Seguretat  3756.970000
# 9                     Trànsit   903.576667

# %%
accions_VALL=accions_VA.copy()
accions_BARCEL=BAR.copy()

fig, axes = plt.subplots(1, 2, figsize=(12, 6))  # Adjust the figure size as needed
pie1 = axes[0].pie(accions_VALL['INCIDENTS'], explode= explode, autopct='%1.1f%%', pctdistance=1.1, startangle=20, shadow=False)
plt.legend(pie1[0], accions_VALL['TIPUS'], bbox_to_anchor=(1, 0.5), loc="best", fontsize=8 )
axes[0].set_title("Vall d'Aran")

# Plot the second pie chart
pie2= axes[1].pie(accions_BARCEL['INCIDENTS'], explode= explode, autopct=lambda p: '{:.1f}%'.format(p) if p > 1 else '', pctdistance=1.1, startangle=20, shadow=False)
plt.legend(pie2[0], accions_BARCEL['TIPUS'], bbox_to_anchor=(1, 0.5), loc="best", fontsize=8 )
axes[1].set_title('Barcelonès')

# Adjust layout to prevent overlap
plt.savefig('./figures/comparation_incidents.pdf')
plt.tight_layout()

# Show the plot
plt.show()

# %%
incidents_salvament= pd.read_csv(direc + 'Dades_d_incidents_operatius_gestionats_pel_CAT112_20231110.csv' )
incidents_salvament= incidents_salvament[(incidents_salvament["ANY"]<=2022) & (incidents_salvament["ANY"]>=2018)]

# incidents_BAR= incidents_salvament[(incidents_salvament['COMARCA']=="BARCELONES")]
# incidents_BAR.head()
# Out:
# array(['CONCA DE BARBERA', "PLA D'URGELL", 'SELVA', 'VALLES ORIENTAL',
#        'CERDANYA', 'ANOIA', 'ALT CAMP', 'VALLES OCCIDENTAL', 'MONTSIA',
#        'SEGRIA', 'GARROTXA', 'BAIX PENEDES', 'GIRONES', 'OSONA',
#        'ALT URGELL', 'NOGUERA', 'MARESME', 'ALT EMPORDA',
#        'BAIX LLOBREGAT', 'BAIX EMPORDA', 'ALT PENEDES', 'SOLSONES',
#        'TARRAGONES', "RIBERA D'EBRE", 'GARRAF', 'PALLARS SOBIRA',
#        'BERGUEDA', 'BAGES', 'BAIX CAMP', 'GARRIGUES', 'BAIX EBRE',
#        'SEGARRA', "PLA DE L'ESTANY", 'PRIORAT', "VAL D'ARAN",
#        'BARCELONES', 'URGELL', 'RIPOLLES', 'ALTA RIBAGORÇA', 'TERRA ALTA',
#        'MOIANES', 'PALLARS JUSSA', nan], dtype=object)

# %%
incidents_salvament['COMARCA'].unique()


pla
