# %% [markdown]
# # Correlations between rescue actions and 112 incidents in sea-rivers-topics geographically

# %% [markdown]
# 1. [Obtaing data from rescue actions](#1)
#     1.1. [Grouped rescues](#1.1)
# 2. [Obtaing data 112 actions](#2)
#     2.1. [Grouped data river-sea-like incidents](#2.1)
# 3. [Merging data](#3)

# %%
import numpy as np
import pandas as pd

# %%
direc = '../dades/'

# %% [markdown]
# ## Obtaining data from rescue actions <a class="anchor" id="1"></a>

# %%
accions_salvament = pd.read_csv(direc+'Actuacions_en_salvaments_al_medi_natural_dels_Bombers_de_la_Generalitat_20231109.csv')
accions_filtrades= accions_salvament[(accions_salvament["ANY"]<2023) & (accions_salvament["ANY"]>2017)]   #AND & OR |

# show loaded table:
accions_filtrades['TAL_NOM_ALARMA'].unique()
# Out:
# array(['Salvament i/o rescat de muntanya',
#        'Salvament i/o recerca i/o rescat en medi fluvial (rius,barrancs, llacs)',
#        'Recerca persones perdudes o desaparegudes',
#        'Salvament i/o recerca i/o rescat en medi marítim',
#        'Salvament i/o rescat en coves i pous', 'Rescat de muntanya',
#        'Recerca persones perdudes', 'Recerca i/o rescat en medi marítim',
#        'Recerca i/o rescat en medi fluvial (rius, barrancs, llacs)',
#        'Rescat en coves i pous'], dtype=object)

# %%
#MAR_RIU - Salvament i/o recerca i/o rescat en medi fluvial (rius,barrancs, llacs) - Salvament i/o recerca i/o rescat en medi marítim - Recerca i/o rescat en medi marítim - Recerca i/o rescat en medi fluvial (rius, barrancs, llacs) 
accions_descartades_muntanya = ['Salvament i/o recerca i/o rescat en medi fluvial (rius,barrancs, llacs)',
       'Salvament i/o recerca i/o rescat en medi marítim', 'Recerca i/o rescat en medi marítim',
       'Recerca i/o rescat en medi fluvial (rius, barrancs, llacs)']

salvam_riu = accions_filtrades[~accions_filtrades['TAL_NOM_ALARMA'].isin(accions_descartades_muntanya)]

salvam_riu= salvam_riu.reset_index(drop=True)

salvam_riu

# resultado = salvam_riu.loc[salvam_riu['MUNICIPI'] == 'Llançà']
# resultado
# Out:
#       ACT_NUM_ACTUACIO           NOM REGIO TAL_COD_ALARMA1 TGA_NOM_GRUPO  \
# 0            220317846              Lleida              SV    salvaments
# 1            220424995           Tarragona              SV    salvaments
# 2            222433564   Metropolitana Sud              SV    salvaments
# 3            222703229     U.F. Val d'Aran              SV    salvaments
# 4            222318655              Centre              SV    salvaments
# ...                ...                 ...             ...           ...
# 7569         182400135   Metropolitana Sud              SV    salvaments
# 7570         182600035    Terres de l'Ebre              SV    salvaments
# 7571         180200036              Girona              SV    salvaments
# 7572         182500054  Metropolitana Nord              SV    salvaments
# 7573         182500092  Metropolitana Nord              SV    salvaments
#
#      TAL_COD_ALARMA2                    TAL_NOM_ALARMA  CODI_INE  \
# 0                 MU  Salvament i/o rescat de muntanya     25089
# 1                 MU  Salvament i/o rescat de muntanya     43049
# 2                 MU  Salvament i/o rescat de muntanya      8270
# 3                 MU  Salvament i/o rescat de muntanya     25025
# 4                 MU  Salvament i/o rescat de muntanya     17006
# ...              ...                               ...       ...
# 7569              MU                Rescat de muntanya      8231
# 7570              MU                Rescat de muntanya     43136
# 7571              MU                Rescat de muntanya     17032
# 7572              RC         Recerca persones perdudes      8120
# 7573              MU                Rescat de muntanya      8202
#
#                       MUNICIPI              NOM_POBLACIO  CODI_COMARCA  ...  \
# 0                      Farrera               Montesclado            26  ...
# 1       Cornudella de Montsant                   Siurana            29  ...
# 2                       Sitges                    Sitges            17  ...
# 3                    Naut Aran                 Naut Aran            39  ...
# 4                          Alp                       Alp            15  ...
# ...                        ...                       ...           ...  ...
# 7569        Sant Pere de Ribes        Sant Pere de Ribes            17  ...
# 7570  Sant Carles de la Ràpita  Sant Carles de la Ràpita            22  ...
# 7571                  Cadaqués                  Cadaqués             2  ...
# 7572                Matadepera                Matadepera            40  ...
# 7573               Sant Celoni               Sant Celoni            41  ...
#
#        ANY  MES  ACT_DAT_ACTUACIO ACT_X_UTM  ACT_Y_UTM  CODI_REGIO  VALIDAT  \
# 0     2022   12        31/12/2022  359029.0  4703443.0           3        S
# 1     2022   12        31/12/2022  326877.0  4569430.0           4        S
# 2     2022   12        31/12/2022  396692.0  4564042.0          24        S
# 3     2022   12        31/12/2022  335546.0  4726173.0          27        S
# 4     2022   12        31/12/2022  409042.0  4687406.0          23        S
# ...    ...  ...               ...       ...        ...         ...      ...
# 7569  2018    1        02/01/2018  394233.0  4569117.0          24       SI
# 7570  2018    1        02/01/2018  292357.0  4500888.0          26       SI
# 7571  2018    1        01/01/2018  524808.0  4684559.0           2       SI
# 7572  2018    1        01/01/2018  418314.0  4610776.0          25       SI
# 7573  2018    1        01/01/2018  465176.0  4614041.0          25       SI
#
#       LONGITUD    LATITUD                           GEOREFERÈNCIA
# 0     1.285146  42.470508   POINT (1.285146163115 42.47050799814)
# 1     0.933488  41.257753  POINT (0.933487648042 41.257752634189)
# 2     1.767511  41.221172  POINT (1.767511104528 41.221172153671)
# 3     0.993092  42.670455  POINT (0.993092440136 42.670455109079)
# 4     1.895928  42.333593  POINT (1.895928288604 42.333593201755)
# ...        ...        ...                                     ...
# 7569  1.737302  41.266558                                     NaN
# 7570  0.544737  40.632747                                     NaN
# 7571  3.301029  42.312873                                     NaN
# 7572  2.019110  41.644542                                     NaN
# 7573  2.581617  41.677374                                     NaN
#
# [7574 rows x 21 columns]

# %%
Salvam_riu['NOM_COMARCA'].unique()
# Out:
# array(['Pallars Sobirà', 'Priorat', 'Garraf', "Val d'Aran", 'Cerdanya',
#        'Alt Penedès', 'Baix Camp', 'Baix Llobregat', 'Gironès',
#        'Garrotxa', 'Segrià', 'Ripollès', 'Alt Camp', 'Alt Urgell',
#        'Maresme', 'Vallès Oriental', 'Pallars Jussà', 'Baix Ebre',
#        'Osona', 'Conca de Barberà', 'Alt Empordà', 'Vallès Occidental',
#        'Barcelonès', 'Solsonès', "Pla de l'Estany", 'Bages',
#        'Baix Empordà', "Ribera d'Ebre", 'Tarragonès', 'Alta Ribagorça',
#        'Terra Alta', 'Berguedà', 'Anoia', 'Selva', 'Moianès', 'Noguera',
#        'Montsià', 'Baix Penedès', 'Fora de Catalunya', 'Urgell',
#        'Garrigues', 'Segarra', "Pla d'Urgell"], dtype=object)

# %%
#Turn "municipi" in capital letters

Salvam_riu=salvam_riu.copy()

from unidecode import unidecode
      
def quitar_acentos(cadena):
    # Reemplazar 'ç' por un marcador temporal
    cadena_con_marcador = cadena.replace('ç', '___cedilla___')
    # Aplicar unidecode y luego revertir el marcador temporal
    cadena_sin_acentos = unidecode(cadena_con_marcador).replace('___cedilla___', 'ç')
    
    return cadena_sin_acentos

Salvam_riu['NOM_COMARCA'] = Salvam_riu['NOM_COMARCA'].apply(quitar_acentos)


Salvam_riu['NOM_COMARCA'] = Salvam_riu['NOM_COMARCA'].str.upper()

Salvam_riu

# resultado = Salvam_riu.loc[Salvam_riu['MUNICIPI'] == 'LLANÇA']
# resultado
# Out:
#       ACT_NUM_ACTUACIO           NOM REGIO TAL_COD_ALARMA1 TGA_NOM_GRUPO  \
# 0            220317846              Lleida              SV    salvaments
# 1            220424995           Tarragona              SV    salvaments
# 2            222433564   Metropolitana Sud              SV    salvaments
# 3            222703229     U.F. Val d'Aran              SV    salvaments
# 4            222318655              Centre              SV    salvaments
# ...                ...                 ...             ...           ...
# 7569         182400135   Metropolitana Sud              SV    salvaments
# 7570         182600035    Terres de l'Ebre              SV    salvaments
# 7571         180200036              Girona              SV    salvaments
# 7572         182500054  Metropolitana Nord              SV    salvaments
# 7573         182500092  Metropolitana Nord              SV    salvaments
#
#      TAL_COD_ALARMA2                    TAL_NOM_ALARMA  CODI_INE  \
# 0                 MU  Salvament i/o rescat de muntanya     25089
# 1                 MU  Salvament i/o rescat de muntanya     43049
# 2                 MU  Salvament i/o rescat de muntanya      8270
# 3                 MU  Salvament i/o rescat de muntanya     25025
# 4                 MU  Salvament i/o rescat de muntanya     17006
# ...              ...                               ...       ...
# 7569              MU                Rescat de muntanya      8231
# 7570              MU                Rescat de muntanya     43136
# 7571              MU                Rescat de muntanya     17032
# 7572              RC         Recerca persones perdudes      8120
# 7573              MU                Rescat de muntanya      8202
#
#                       MUNICIPI              NOM_POBLACIO  CODI_COMARCA  ...  \
# 0                      Farrera               Montesclado            26  ...
# 1       Cornudella de Montsant                   Siurana            29  ...
# 2                       Sitges                    Sitges            17  ...
# 3                    Naut Aran                 Naut Aran            39  ...
# 4                          Alp                       Alp            15  ...
# ...                        ...                       ...           ...  ...
# 7569        Sant Pere de Ribes        Sant Pere de Ribes            17  ...
# 7570  Sant Carles de la Ràpita  Sant Carles de la Ràpita            22  ...
# 7571                  Cadaqués                  Cadaqués             2  ...
# 7572                Matadepera                Matadepera            40  ...
# 7573               Sant Celoni               Sant Celoni            41  ...
#
#        ANY  MES  ACT_DAT_ACTUACIO ACT_X_UTM  ACT_Y_UTM  CODI_REGIO  VALIDAT  \
# 0     2022   12        31/12/2022  359029.0  4703443.0           3        S
# 1     2022   12        31/12/2022  326877.0  4569430.0           4        S
# 2     2022   12        31/12/2022  396692.0  4564042.0          24        S
# 3     2022   12        31/12/2022  335546.0  4726173.0          27        S
# 4     2022   12        31/12/2022  409042.0  4687406.0          23        S
# ...    ...  ...               ...       ...        ...         ...      ...
# 7569  2018    1        02/01/2018  394233.0  4569117.0          24       SI
# 7570  2018    1        02/01/2018  292357.0  4500888.0          26       SI
# 7571  2018    1        01/01/2018  524808.0  4684559.0           2       SI
# 7572  2018    1        01/01/2018  418314.0  4610776.0          25       SI
# 7573  2018    1        01/01/2018  465176.0  4614041.0          25       SI
#
#       LONGITUD    LATITUD                           GEOREFERÈNCIA
# 0     1.285146  42.470508   POINT (1.285146163115 42.47050799814)
# 1     0.933488  41.257753  POINT (0.933487648042 41.257752634189)
# 2     1.767511  41.221172  POINT (1.767511104528 41.221172153671)
# 3     0.993092  42.670455  POINT (0.993092440136 42.670455109079)
# 4     1.895928  42.333593  POINT (1.895928288604 42.333593201755)
# ...        ...        ...                                     ...
# 7569  1.737302  41.266558                                     NaN
# 7570  0.544737  40.632747                                     NaN
# 7571  3.301029  42.312873                                     NaN
# 7572  2.019110  41.644542                                     NaN
# 7573  2.581617  41.677374                                     NaN
#
# [7574 rows x 21 columns]

# %%
#treure totes les columnes que no m'ajuden
#salvam_riu.pop('')
riu_clean = Salvam_riu.copy()
#Salvam_riu.columns.tolist()

riu_clean.pop('TAL_COD_ALARMA1') 
riu_clean.pop('TAL_COD_ALARMA2')
riu_clean.pop('TGA_NOM_GRUPO')
riu_clean.pop('CODI_INE')
riu_clean.pop('NOM_POBLACIO')
riu_clean.pop('MUNICIPI')
riu_clean.pop('ACT_NUM_ACTUACIO')
riu_clean.pop('NOM REGIO')

riu_clean=riu_clean[(riu_clean['VALIDAT'] == 'S') | (riu_clean['VALIDAT'] == 'SI') ]
salva_clean_riu = riu_clean.copy()
salva_clean_riu['ANY-MES'] = pd.to_datetime(salva_clean_riu['ANY'].astype(str) + '-' + salva_clean_riu['MES'].astype(str), format='%Y-%m')
salva_clean_riu.pop('ANY')
salva_clean_riu.pop('MES')
salva_clean_riu.pop('ACT_DAT_ACTUACIO')
salva_clean_riu.pop('VALIDAT')
salva_clean_riu.pop('CODI_COMARCA')
salva_clean_riu.pop('CODI_REGIO')
salvament = salva_clean_riu.copy()
salvament
# Out:
#                         TAL_NOM_ALARMA        NOM_COMARCA  ACT_X_UTM  \
# 0     Salvament i/o rescat de muntanya     PALLARS SOBIRA   359029.0
# 1     Salvament i/o rescat de muntanya            PRIORAT   326877.0
# 2     Salvament i/o rescat de muntanya             GARRAF   396692.0
# 3     Salvament i/o rescat de muntanya         VAL D'ARAN   335546.0
# 4     Salvament i/o rescat de muntanya           CERDANYA   409042.0
# ...                                ...                ...        ...
# 7569                Rescat de muntanya             GARRAF   394233.0
# 7570                Rescat de muntanya            MONTSIA   292357.0
# 7571                Rescat de muntanya        ALT EMPORDA   524808.0
# 7572         Recerca persones perdudes  VALLES OCCIDENTAL   418314.0
# 7573                Rescat de muntanya    VALLES ORIENTAL   465176.0
#
#       ACT_Y_UTM  LONGITUD    LATITUD                           GEOREFERÈNCIA  \
# 0     4703443.0  1.285146  42.470508   POINT (1.285146163115 42.47050799814)
# 1     4569430.0  0.933488  41.257753  POINT (0.933487648042 41.257752634189)
# 2     4564042.0  1.767511  41.221172  POINT (1.767511104528 41.221172153671)
# 3     4726173.0  0.993092  42.670455  POINT (0.993092440136 42.670455109079)
# 4     4687406.0  1.895928  42.333593  POINT (1.895928288604 42.333593201755)
# ...         ...       ...        ...                                     ...
# 7569  4569117.0  1.737302  41.266558                                     NaN
# 7570  4500888.0  0.544737  40.632747                                     NaN
# 7571  4684559.0  3.301029  42.312873                                     NaN
# 7572  4610776.0  2.019110  41.644542                                     NaN
# 7573  4614041.0  2.581617  41.677374                                     NaN
#
#         ANY-MES
# 0    2022-12-01
# 1    2022-12-01
# 2    2022-12-01
# 3    2022-12-01
# 4    2022-12-01
# ...         ...
# 7569 2018-01-01
# 7570 2018-01-01
# 7571 2018-01-01
# 7572 2018-01-01
# 7573 2018-01-01
#
# [7573 rows x 8 columns]

# %% [markdown]
# ### Grouped recue - mountain  <a class="anchor" id="1.1"></a>

# %%
#Grouping all recue actions in the same town in the same month and year
sal = salvament.copy()
sal=pd.DataFrame(sal.groupby(['ANY-MES','NOM_COMARCA','LONGITUD','LATITUD','GEOREFERÈNCIA','ACT_X_UTM','ACT_Y_UTM','TAL_NOM_ALARMA'])['ANY-MES'].count())
sal= sal.rename(columns={'ANY-MES':"SALVAMENTS"})
sal = sal.reset_index()
sal_grouped=sal.copy()

# inc_riu_grouped = pd.DataFrame (inc_riu.groupby(['ANY-MES','PROVINCIA','MUNICIPI','COMARCA'])['INCIDENTS'].sum())

# %% [markdown]
# ## Importing data from 112 incidents <a class="anchor" id="2"></a>

# %%
trucades_salvament= pd.read_csv(direc + 'Dades_d_incidents_operatius_gestionats_pel_CAT112_20231110.csv' )
trucades_filtrades= trucades_salvament[(trucades_salvament["ANY"]<2023) & (trucades_salvament["ANY"]>2017)]

trucades_filtrades['COMARCA'].unique()
# Out:
# array(['CONCA DE BARBERA', "PLA D'URGELL", 'SELVA', 'VALLES ORIENTAL',
#        'CERDANYA', 'ANOIA', 'ALT CAMP', 'VALLES OCCIDENTAL', 'MONTSIA',
#        'SEGRIA', 'GARROTXA', 'BAIX PENEDES', 'GIRONES', 'OSONA',
#        'ALT URGELL', 'NOGUERA', 'MARESME', 'ALT EMPORDA',
#        'BAIX LLOBREGAT', 'BAIX EMPORDA', 'ALT PENEDES', 'SOLSONES',
#        'TARRAGONES', "RIBERA D'EBRE", 'GARRAF', 'PALLARS SOBIRA',
#        'BERGUEDA', 'BAGES', 'BAIX CAMP', 'GARRIGUES', 'BAIX EBRE',
#        'SEGARRA', "PLA DE L'ESTANY", 'PRIORAT', "VAL D'ARAN",
#        'BARCELONES', 'URGELL', 'RIPOLLES', 'ALTA RIBAGORÇA', 'TERRA ALTA',
#        'MOIANES', 'PALLARS JUSSA', nan], dtype=object)

# %%
#Incidents utils comparables
incidents_descartats=['Seguretat','Trànsit','Civisme']

incidents = trucades_filtrades[~trucades_filtrades['TIPUS'].isin(incidents_descartats)]
incidents = incidents.reset_index(drop=True)
incidents

# %%
#focusing in river sea actions:

incidents_desc_riumar = ['Altres incidències', 'Accidents']
         

incidents_riu = incidents[~incidents['TIPUS'].isin(incidents_desc_riumar)]
incidents_riu['TIPUS'].unique()
incidents_riu['ANY-MES'] = pd.to_datetime(incidents_riu['ANY'].astype(str) + '-' + incidents_riu['MES'].astype(str), format='%Y-%m')
incidents_riu.pop('ANY')
incidents_riu.pop('MES')
inc_riu = incidents_riu
inc_riu

# %% [markdown]
# ### Obtaining data of river-sea-like rescues of the incidents at each town each month <a class="anchor" id="2.1"></a>

# %%
#Grouping all incidenst in the same town in the same month and year

inc_riu_grouped = pd.DataFrame (inc_riu.groupby(['ANY-MES','PROVINCIA','MUNICIPI','COMARCA'])['INCIDENTS'].sum())

inc_riu_grouped= inc_riu_grouped.reset_index()

inc_riu_grouped.drop_duplicates()

# %% [markdown]
# ## Merging data <a class="anchor" id="3"></a>

# %%
#Merging rescue actions with incidents of river and sea nature

merge_sea = pd.merge(inc_riu_grouped,sal_grouped, on=['MUNICIPI','ANY-MES'])
merge_sea

# %%
# Ejemplo de DataFrames
data1 = {'col1': [1, 2, 3,2],
         'col2': ['A', 'B', 'C','B'],
         'col3': ['X', 'Y', 'Z','Y'],
         'value_df1': [10, 20, 30,40],
        'value_df12':[1,1,1,4]}

data2 = {'col1': [2, 3, 4],
         'col2': ['B', 'C', 'D'],
         'col3': ['Y', 'Z', 'W'],
         'value_df2': [40, 50, 60]}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# Combinar DataFrames en función de las columnas 'col1', 'col2' y 'col3'
result = pd.merge(df1, df2, on=['col1', 'col2', 'col3'])

# Imprimir el resultado
result
