# %% [markdown]
# ### Table of contents
# 1. [Import libraries](#Import-libraries)
# 2. [Total rescue actions map (2018-2022)](#2.-Total-rescue-actions-map)
#     1. [Data exploration](#2.A-Data-exploration)
#     2. [Catalonia map](#2.B-Catalonia-map)
#     3. [A first geographical plot ](#2.C-A-first-geographical-plot)
# 3. [Civil protection plans (2018-2022)](#3.-Civil-protection-plans)
#     1. [Data exploration](#3.A.-Data-exploration)
#         1. [Extramunicipal PP](#Supramunicipal-protection-plans)
#         2. [Municipal PP](#Municipal-protection-plans)
#     2. [Homologation, update and revision of PP by county](#3.B-Homologation,-update-and-revision-of-PP-by-county)
#     3. [A second geographical plot](#3.C-A-second-geographical-plot)
# 4. [Map panel](#4.-Map-panel)
# 5. [Rescue/ CPP study of Osona](#5.-Rescue/-CPP-study-of-Osona)
#     1. [Rescue actions study of Osona](#5.A-Rescue-actions-study-of-Osona)
#     2. [CPP action in Osona](#5.B-CPP-action-in-Osona)
#     3. [Osona rescue/CPP action panel](#5.C-Osona-rescue/CPP-action-panel)
# 6. [Rescue/ CPP study of Baix Llobregat](#6.-Rescue/-CPP-study-of-Baix-Llobregat)
#     1. [Rescue actions study of Baix Llobregat](#6.A-Rescue-actions-study-of-Baix-Llobregat)
#     2. [CPP action in Baix Llobregat](#6.B-CPP-action-in-Baix-Llobregat)
#     3. [Baix Llobregat rescue/CPP action panel](#6.C-Baix-Llobregat-rescue/CPP-action-panel)
# 7. [Rescue/ CPP study of Val d'Aran](#7.-Rescue/-CPP-study-of-Val-d'Aran)
#     1. [Rescue actions study of Val d'Aran](#7.A-Rescue-actions-study-of-Val-d'Aran)
#     2. [CPP action in Val d'Aran](#7.B-CPP-action-in-Val-d'Aran)

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import geopandas as gpd
import geodatasets
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import math
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Set data directory

# %%
data_dir = '../dades/'

# %% [markdown]
# ### 2. Total rescue actions map
# The first information we are interested in is finding a geographical plot containing all the rescue actions carried out by the Fire Department between 2018 and 2022, in order to indentify which how rescue actions (of any kind) are distributed geographically.

# %%
#load data
rescue_actions = pd.read_csv(data_dir+'Actuacions_en_salvaments_al_medi_natural_dels_Bombers_de_la_Generalitat_20231109.csv')

# %% [markdown]
# #### 2.A Data exploration
# Exploration of data, in order to find if any formatting is needed in order te treat the data.

# %%
rescue_actions.head()
# Out:
#    ACT_NUM_ACTUACIO           NOM REGIO TAL_COD_ALARMA1 TGA_NOM_GRUPO  \
# 0         232539916  Metropolitana Nord              SV    salvaments
# 1         230315085              Lleida              SV    salvaments
# 2         232315301              Centre              SV    salvaments
# 3         230229809              Girona              SV    salvaments
# 4         230229850              Girona              SV    salvaments
#
#   TAL_COD_ALARMA2                      TAL_NOM_ALARMA  CODI_INE  \
# 0              MU    Salvament i/o rescat de muntanya      8261
# 1              MU    Salvament i/o rescat de muntanya     25043
# 2              MU    Salvament i/o rescat de muntanya      8175
# 3              MU    Salvament i/o rescat de muntanya     17095
# 4              RA  Acompanyament de persones perdudes     17185
#
#               MUNICIPI         NOM_POBLACIO  CODI_COMARCA  ...   ANY  MES  \
# 0        Santa Susanna        Santa Susanna            21  ...  2023   10
# 1      Vall de Boí, La      Vall de Boí, La             5  ...  2023   10
# 2            Puig-reig            Cal Riera            14  ...  2023   10
# 3        Lloret de Mar        Lloret de Mar            34  ...  2023   10
# 4  Sant Joan les Fonts  Sant Joan les Fonts            19  ...  2023   10
#
#    ACT_DAT_ACTUACIO ACT_X_UTM  ACT_Y_UTM  CODI_REGIO  VALIDAT  LONGITUD  \
# 0        08/10/2023  474668.0  4610652.0          25        N  2.695798
# 1        08/10/2023  324638.0  4719040.0           3        N  0.862264
# 2        08/10/2023  407110.0  4642434.0          23        N  1.879642
# 3        08/10/2023  487480.0  4620337.0           2        N  2.849448
# 4        08/10/2023  463030.0  4673271.0           2        N  2.552117
#
#      LATITUD                           GEOREFERÈNCIA
# 0  41.647208  POINT (2.695797715126 41.647207730681)
# 1  42.603854  POINT (0.862264040642 42.603853695832)
# 2  41.928405   POINT (1.879641578211 41.92840451498)
# 3  41.734746  POINT (2.849448083699 41.734745914847)
# 4  42.210731   POINT (2.55211709702 42.210731354776)
#
# [5 rows x 21 columns]

# %% [markdown]
# What columns does the dataframe have?

# %%
rescue_actions.columns
# Out:
# Index(['ACT_NUM_ACTUACIO', 'NOM REGIO', 'TAL_COD_ALARMA1', 'TGA_NOM_GRUPO',
#        'TAL_COD_ALARMA2', 'TAL_NOM_ALARMA', 'CODI_INE', 'MUNICIPI',
#        'NOM_POBLACIO', 'CODI_COMARCA', 'NOM_COMARCA', 'ANY', 'MES',
#        'ACT_DAT_ACTUACIO', 'ACT_X_UTM', 'ACT_Y_UTM', 'CODI_REGIO', 'VALIDAT',
#        'LONGITUD', 'LATITUD', 'GEOREFERÈNCIA'],
#       dtype='object')

# %% [markdown]
# We will only study the time window between 2018-2022

# %%
rescue_actions[(rescue_actions["ANY"] >= 2018) & (rescue_actions["ANY"]<= 2022)]
# Out:
#        ACT_NUM_ACTUACIO           NOM REGIO TAL_COD_ALARMA1 TGA_NOM_GRUPO  \
# 1794          220317846              Lleida              SV    salvaments
# 1795          220424995           Tarragona              SV    salvaments
# 1796          222433564   Metropolitana Sud              SV    salvaments
# 1797          222703229     U.F. Val d'Aran              SV    salvaments
# 1798          222318655              Centre              SV    salvaments
# ...                 ...                 ...             ...           ...
# 10232         182600035    Terres de l'Ebre              SV    salvaments
# 10233         182500044  Metropolitana Nord              SV    salvaments
# 10234         180200036              Girona              SV    salvaments
# 10235         182500054  Metropolitana Nord              SV    salvaments
# 10236         182500092  Metropolitana Nord              SV    salvaments
#
#       TAL_COD_ALARMA2                      TAL_NOM_ALARMA  CODI_INE  \
# 1794               MU    Salvament i/o rescat de muntanya     25089
# 1795               MU    Salvament i/o rescat de muntanya     43049
# 1796               MU    Salvament i/o rescat de muntanya      8270
# 1797               MU    Salvament i/o rescat de muntanya     25025
# 1798               MU    Salvament i/o rescat de muntanya     17006
# ...               ...                                 ...       ...
# 10232              MU                  Rescat de muntanya     43136
# 10233              MR  Recerca i/o rescat en medi marítim      8121
# 10234              MU                  Rescat de muntanya     17032
# 10235              RC           Recerca persones perdudes      8120
# 10236              MU                  Rescat de muntanya      8202
#
#                        MUNICIPI              NOM_POBLACIO  CODI_COMARCA  ...  \
# 1794                    Farrera               Montesclado            26  ...
# 1795     Cornudella de Montsant                   Siurana            29  ...
# 1796                     Sitges                    Sitges            17  ...
# 1797                  Naut Aran                 Naut Aran            39  ...
# 1798                        Alp                       Alp            15  ...
# ...                         ...                       ...           ...  ...
# 10232  Sant Carles de la Ràpita  Sant Carles de la Ràpita            22  ...
# 10233                    Mataró                    Mataró            21  ...
# 10234                  Cadaqués                  Cadaqués             2  ...
# 10235                Matadepera                Matadepera            40  ...
# 10236               Sant Celoni               Sant Celoni            41  ...
#
#         ANY  MES  ACT_DAT_ACTUACIO ACT_X_UTM  ACT_Y_UTM  CODI_REGIO  VALIDAT  \
# 1794   2022   12        31/12/2022  359029.0  4703443.0           3        S
# 1795   2022   12        31/12/2022  326877.0  4569430.0           4        S
# 1796   2022   12        31/12/2022  396692.0  4564042.0          24        S
# 1797   2022   12        31/12/2022  335546.0  4726173.0          27        S
# 1798   2022   12        31/12/2022  409042.0  4687406.0          23        S
# ...     ...  ...               ...       ...        ...         ...      ...
# 10232  2018    1        02/01/2018  292357.0  4500888.0          26       SI
# 10233  2018    1        01/01/2018  454218.0  4597542.0          25       SI
# 10234  2018    1        01/01/2018  524808.0  4684559.0           2       SI
# 10235  2018    1        01/01/2018  418314.0  4610776.0          25       SI
# 10236  2018    1        01/01/2018  465176.0  4614041.0          25       SI
#
#        LONGITUD    LATITUD                           GEOREFERÈNCIA
# 1794   1.285146  42.470508   POINT (1.285146163115 42.47050799814)
# 1795   0.933488  41.257753  POINT (0.933487648042 41.257752634189)
# 1796   1.767511  41.221172  POINT (1.767511104528 41.221172153671)
# 1797   0.993092  42.670455  POINT (0.993092440136 42.670455109079)
# 1798   1.895928  42.333593  POINT (1.895928288604 42.333593201755)
# ...         ...        ...                                     ...
# 10232  0.544737  40.632747                                     NaN
# 10233  2.451231  41.528215                                     NaN
# 10234  3.301029  42.312873                                     NaN
# 10235  2.019110  41.644542                                     NaN
# 10236  2.581617  41.677374                                     NaN
#
# [8443 rows x 21 columns]

# %% [markdown]
# Make a copy of filtered by year results

# %%
filt_rescues = rescue_actions[(rescue_actions["ANY"] >= 2018) & (rescue_actions["ANY"]<= 2022)].copy(deep = True)

# %% [markdown]
# Is there a standard numenclature for the type of rescue type?

# %%
filt_rescues["TAL_NOM_ALARMA"].unique()
# Out:
# array(['Salvament i/o rescat de muntanya',
#        'Salvament i/o recerca i/o rescat en medi fluvial (rius,barrancs, llacs)',
#        'Recerca persones perdudes o desaparegudes',
#        'Salvament i/o recerca i/o rescat en medi marítim',
#        'Salvament i/o rescat en coves i pous', 'Rescat de muntanya',
#        'Recerca persones perdudes', 'Recerca i/o rescat en medi marítim',
#        'Recerca i/o rescat en medi fluvial (rius, barrancs, llacs)',
#        'Rescat en coves i pous'], dtype=object)

# %% [markdown]
# What data type is used for the dates?

# %%
type(filt_rescues.iloc[0]["ACT_DAT_ACTUACIO"])
# Out:
# str

# %% [markdown]
# If we need to deal with those dates, we will need to transform those into time-stamp format.

# %% [markdown]
# Are county names unique (standarized names)?

# %%
filt_rescues["NOM_COMARCA"].unique()
# Out:
# array(['Pallars Sobirà', 'Priorat', 'Garraf', "Val d'Aran", 'Cerdanya',
#        'Alt Penedès', 'Bages', 'Baix Camp', 'Baix Llobregat', 'Gironès',
#        'Garrotxa', 'Segrià', 'Ripollès', 'Alt Camp', 'Alt Urgell',
#        'Maresme', 'Vallès Oriental', 'Pallars Jussà', 'Baix Ebre',
#        'Osona', 'Vallès Occidental', 'Conca de Barberà', 'Alt Empordà',
#        'Barcelonès', 'Solsonès', "Pla de l'Estany", 'Baix Empordà',
#        "Ribera d'Ebre", 'Tarragonès', 'Alta Ribagorça', 'Terra Alta',
#        'Berguedà', 'Anoia', 'Selva', 'Moianès', 'Noguera', 'Montsià',
#        'Baix Penedès', 'Fora de Catalunya', 'Urgell', "Pla d'Urgell",
#        'Garrigues', 'Segarra'], dtype=object)

# %% [markdown]
# How many rescue actions by county in 2018-2022 period? Drop other columns we do not need.

# %%
rescue_tot_comarca = filt_rescues[["CODI_COMARCA", "NOM_COMARCA","ACT_NUM_ACTUACIO"]].groupby(["CODI_COMARCA", "NOM_COMARCA"]).count().copy(deep = True).reset_index()
rescue_tot_comarca.head()
# Out:
#    CODI_COMARCA        NOM_COMARCA  ACT_NUM_ACTUACIO
# 0             0  Fora de Catalunya                 8
# 1             1           Alt Camp                80
# 2             2        Alt Empordà               398
# 3             3        Alt Penedès               120
# 4             4         Alt Urgell               192

# %%
#We are only interested in rescue actions in Catalonia, se we need to pop 'Fora de Catalunya'
rescue_tot_comarca.drop(0, inplace =  True)

# %%
rescue_tot_comarca.head()
# Out:
#    CODI_COMARCA     NOM_COMARCA  ACT_NUM_ACTUACIO
# 1             1        Alt Camp                80
# 2             2     Alt Empordà               398
# 3             3     Alt Penedès               120
# 4             4      Alt Urgell               192
# 5             5  Alta Ribagorça               196

# %% [markdown]
# What are the counties with most rescue actions?

# %%
rescue_tot_comarca.sort_values(by='ACT_NUM_ACTUACIO', ascending = False).head()
# Out:
#     CODI_COMARCA        NOM_COMARCA  ACT_NUM_ACTUACIO
# 11            11     Baix Llobregat               527
# 40            40  Vallès Occidental               517
# 39            39         Val d'Aran               500
# 31            31           Ripollès               479
# 14            14           Berguedà               417

# %% [markdown]
# #### 2.B Catalonia map
# Read a Catalonia map dated in 2022 (we need to exclude the recently added county Lluçanès)

# %%
cat = gpd.read_file(data_dir + "divisions-administratives-v2r1-comarques-100000-20220801.shx")
cat.rename(columns = {'NOMCOMAR':'NOM_COMARCA'}, inplace = True)
cat.head()
# Out:
#   CODICOMAR     NOM_COMARCA                CAPCOMAR  AREAC5000  \
# 0        01        Alt Camp                   Valls   537.6317
# 1        02     Alt Empordà                Figueres  1356.6431
# 2        03     Alt Penedès  Vilafranca del Penedès   592.5498
# 3        04      Alt Urgell         la Seu d'Urgell  1447.2028
# 4        05  Alta Ribagorça        el Pont de Suert   427.2234
#
#                                             geometry
# 0  POLYGON ((373635.755 4592021.079, 373669.333 4...
# 1  MULTIPOLYGON (((514495.140 4662167.740, 514492...
# 2  POLYGON ((385914.163 4595999.962, 386085.364 4...
# 3  MULTIPOLYGON (((360736.000 4649167.000, 360624...
# 4  POLYGON ((326572.730 4721574.001, 326622.339 4...

# %% [markdown]
# Merging of DataFrames.

# %%
merged_rescue_tot = rescue_tot_comarca.merge(cat, how='left', on='NOM_COMARCA')
# merged_rescue_tot_gpd = gpd.GeoDataFrame(merged_rescue_tot, geometry="geometry", crs="EPSG:4326")
merged_rescue_tot_gpd = gpd.GeoDataFrame(merged_rescue_tot, geometry="geometry")
merged_rescue_tot.head()
# Out:
#    CODI_COMARCA     NOM_COMARCA  ACT_NUM_ACTUACIO CODICOMAR  \
# 0             1        Alt Camp                80        01
# 1             2     Alt Empordà               398        02
# 2             3     Alt Penedès               120        03
# 3             4      Alt Urgell               192        04
# 4             5  Alta Ribagorça               196        05
#
#                  CAPCOMAR  AREAC5000  \
# 0                   Valls   537.6317
# 1                Figueres  1356.6431
# 2  Vilafranca del Penedès   592.5498
# 3         la Seu d'Urgell  1447.2028
# 4        el Pont de Suert   427.2234
#
#                                             geometry
# 0  POLYGON ((373635.755 4592021.079, 373669.333 4...
# 1  MULTIPOLYGON (((514495.140 4662167.740, 514492...
# 2  POLYGON ((385914.163 4595999.962, 386085.364 4...
# 3  MULTIPOLYGON (((360736.000 4649167.000, 360624...
# 4  POLYGON ((326572.730 4721574.001, 326622.339 4...

# %% [markdown]
# #### 2.C A first geographical plot
# Total number of rescue actions between 2018 and 2022.

# %%
#highlight the counties with most rescue actions
colors = {"Baix Llobregat":'darkorange',
          "Vallès Occidental":'palegreen',
          "Val d'Aran":'mediumorchid',
          "Ripollès":'gold',
          "Berguedà":'darkred'}

fig, ax = plt.subplots(1,1,figsize=(6,4))
ax.set_xticks([])
ax.set_yticks([])
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('none')
norm = LogNorm()

plot = merged_rescue_tot_gpd.plot(column = 'ACT_NUM_ACTUACIO',
                                  ax=ax,
                                  legend=False,
                                  cmap='Blues',
                                  norm = norm,
                                  legend_kwds={'orientation': "horizontal", 'pad': 0.2})
merged_rescue_tot_gpd.boundary.plot(ax = ax, linewidth = 0.2, color = 'black')
merged_rescue_tot_gpd = merged_rescue_tot_gpd.set_index("NOM_COMARCA")
merged_rescue_tot_gpd.loc[list(colors.keys()),:].boundary.plot(ax=ax,color=list(colors.values()), linewidth = 1.5)
merged_rescue_tot_gpd = merged_rescue_tot_gpd.reset_index()
cbar = fig.colorbar(plot.get_children()[0], ax = ax, label = r'num. rescue actions 2018-2022')
cb_ax = fig.axes[1] 
# cb_ax.tick_params(labelsize=10)
plt.savefig('figures/total_num_2018_2022.pdf')
plt.show()

# %% [markdown]
# ### 3. Civil protection plans

# %% [markdown]
# Import data

# %%
#import
prot_plans = pd.read_csv(data_dir+'Registre_general_de_plans_de_protecci__civil_de_Catalunya_20231109.csv')

# %% [markdown]
# #### 3.A. Data exploration

# %%
prot_plans.head()
# Out:
#   Tipus pla  Número d'inscripció  \
# 0         -                 2208
# 1         -                 1296
# 2         E                 2654
# 3         E                 2941
# 4         E                 2423
#
#                                          Nom del pla  \
# 0  PA PROCICAT - Emergències Episodis Contaminaci...
# 1  PA del PROCICAT per Subsidència al barri de l'...
# 2                      PAM INFOCAT La Selva del Camp
# 3                              PAM SISMICAT Queralbs
# 4                               PAM INFOCAT Arsèguel
#
#                           Estat Data d'homologació Últim esdeveniment  \
# 0       Aprovat pendent revisió                NaN      Actualització
# 1                       Revisió                NaN      Actualització
# 2  Homologat pendent de revisió         22/10/2009        Homologació
# 3  Homologat pendent de revisió         08/09/2010        Homologació
# 4  Homologat pendent de revisió         09/07/2009        Homologació
#
#   Data de l'últim esdeveniment     Ine5        Municipi     Comarca  \
# 0                   13/02/2014      NaN             NaN         NaN
# 1                   26/04/2012      NaN             NaN         NaN
# 2                   22/10/2009  43145.0  Selva del Camp   Baix Camp
# 3                   08/09/2010  17043.0        Queralbs    Ripollès
# 4                   09/07/2009  25032.0        Arsèguel  Alt Urgell
#
#    Servei territorial            Vegueria  Província
# 0                 NaN                 NaN        NaN
# 1                 NaN                 NaN        NaN
# 2           Tarragona           Tarragona  Tarragona
# 3              Girona              Girona     Girona
# 4  Alt Pirineu i Aran  Alt Pirineu i Aran     Lleida

# %% [markdown]
# We only need data for updates/homologation/revision over the period 2018-2022. What is the time format?

# %%
prot_plans["Data de l'últim esdeveniment"].loc[0]
# Out:
# '13/02/2014'

# %% [markdown]
# És type string, canviem a datetime

# %%
prot_plans["Data d'homologació"] = pd.to_datetime(prot_plans["Data d'homologació"], format='%d/%m/%Y')
prot_plans["Data de l'últim esdeveniment"] = pd.to_datetime(prot_plans["Data de l'últim esdeveniment"], format='%d/%m/%Y')

# %%
prot_plans["Data de l'últim esdeveniment"].loc[0]
# Out:
# Timestamp('2014-02-13 00:00:00')

# %% [markdown]
# We can use this code to find the year of each entry

# %%
prot_plans["Data de l'últim esdeveniment"].loc[0].year
# Out:
# 2014

# %% [markdown]
# Filter between 2018-2022, sort by ascending date and make a copy.

# %%
filt_prot_plans = prot_plans[(prot_plans["Data de l'últim esdeveniment"].dt.year >= 2018) & (prot_plans["Data de l'últim esdeveniment"].dt.year <= 2022)].sort_values(by = "Data de l'últim esdeveniment").copy(deep = True)

# %%
filt_prot_plans.head()
# Out:
#      Tipus pla  Número d'inscripció  \
# 2190         E                 5682
# 2748         E                 5709
# 4551         E                 5603
# 2260         E                 5662
# 2259         T                 5542
#
#                                             Nom del pla  \
# 2190                               PAM TRANSCAT Amposta
# 2748  PA PROCICAT - Emergències Episodis Contaminaci...
# 4551                             PAM INUNCAT Vilagrassa
# 2260  PA PROCICAT - Emergències Episodis Contaminaci...
# 2259                              PBEM Ivars de Noguera
#
#                              Estat Data d'homologació Últim esdeveniment  \
# 2190  Homologat pendent de revisió         2018-12-05        Homologació
# 2748  Homologat pendent de revisió         2018-12-05        Homologació
# 4551  Homologat pendent de revisió         2018-12-05        Homologació
# 2260  Homologat pendent de revisió         2018-12-05        Homologació
# 2259  Homologat pendent de revisió         2018-12-05        Homologació
#
#      Data de l'últim esdeveniment     Ine5          Municipi        Comarca  \
# 2190                   2018-12-05  43014.0           Amposta        Montsià
# 2748                   2018-12-05  43065.0            Garcia  Ribera d'Ebre
# 4551                   2018-12-05  25244.0        Vilagrassa         Urgell
# 2260                   2018-12-05  43171.0         Vila-seca     Tarragonès
# 2259                   2018-12-05  25112.0  Ivars de Noguera        Noguera
#
#      Servei territorial          Vegueria  Província
# 2190   Terres de l'Ebre  Terres de l'Ebre  Tarragona
# 2748   Terres de l'Ebre  Terres de l'Ebre  Tarragona
# 4551             Lleida            Lleida     Lleida
# 2260          Tarragona         Tarragona  Tarragona
# 2259             Lleida            Lleida     Lleida

# %% [markdown]
# ##### Supramunicipal protection plans

# %%
filt_prot_plans[filt_prot_plans['Província'].isnull()]
# Out:
#      Tipus pla  Número d'inscripció                               Nom del pla  \
# 4682         E                   22                                   INFOCAT
# 4680         E                    4                                  SISMICAT
# 4681         E                 6348  Pla Especial d’emergències per Pandèmies
# 4655         T                    1                                  PROCICAT
# 643          E                    5                                  TRANSCAT
# 645          E                 2899                                    RADCAT
#
#                         Estat Data d'homologació Últim esdeveniment  \
# 4682  Aprovat pendent revisió                NaT      Actualització
# 4680                  Aprovat                NaT      Actualització
# 4681                  Aprovat                NaT          Aprovació
# 4655                  Aprovat                NaT          Aprovació
# 643                   Aprovat                NaT      Actualització
# 645   Aprovat pendent revisió                NaT      Actualització
#
#      Data de l'últim esdeveniment  Ine5 Municipi Comarca Servei territorial  \
# 4682                   2021-12-10   NaN      NaN     NaN                NaN
# 4680                   2021-12-10   NaN      NaN     NaN                NaN
# 4681                   2022-03-29   NaN      NaN     NaN                NaN
# 4655                   2022-05-31   NaN      NaN     NaN                NaN
# 643                    2022-10-06   NaN      NaN     NaN                NaN
# 645                    2022-10-06   NaN      NaN     NaN                NaN
#
#      Vegueria Província
# 4682      NaN       NaN
# 4680      NaN       NaN
# 4681      NaN       NaN
# 4655      NaN       NaN
# 643       NaN       NaN
# 645       NaN       NaN

# %% [markdown]
# ##### Municipal protection plans

# %%
filt_prot_plans[filt_prot_plans['Província'].notnull()]
# Out:
#      Tipus pla  Número d'inscripció  \
# 2190         E                 5682
# 2748         E                 5709
# 4551         E                 5603
# 2260         E                 5662
# 2259         T                 5542
# ...        ...                  ...
# 1909         E                10640
# 2468         T                10651
# 1349         T                10776
# 2592         E                10793
# 2270         E                10656
#
#                                             Nom del pla  \
# 2190                               PAM TRANSCAT Amposta
# 2748  PA PROCICAT - Emergències Episodis Contaminaci...
# 4551                             PAM INUNCAT Vilagrassa
# 2260  PA PROCICAT - Emergències Episodis Contaminaci...
# 2259                              PBEM Ivars de Noguera
# ...                                                 ...
# 1909                        PAM INUNCAT Sant Joan Despí
# 2468  PA PROCICAT - Malalties Transmissibles Emergen...
# 1349                                      PBEM  Cervera
# 2592                                PAM SISMICAT Mataró
# 2270                              PAM VENTCAT Argentona
#
#                              Estat Data d'homologació Últim esdeveniment  \
# 2190  Homologat pendent de revisió         2018-12-05        Homologació
# 2748  Homologat pendent de revisió         2018-12-05        Homologació
# 4551  Homologat pendent de revisió         2018-12-05        Homologació
# 2260  Homologat pendent de revisió         2018-12-05        Homologació
# 2259  Homologat pendent de revisió         2018-12-05        Homologació
# ...                            ...                ...                ...
# 1909                     Homologat         2022-12-15        Homologació
# 2468                     Homologat         2022-12-15        Homologació
# 1349                     Homologat         2022-12-15            Revisió
# 2592                     Homologat         2022-12-15            Revisió
# 2270                     Homologat         2022-12-15        Homologació
#
#      Data de l'últim esdeveniment     Ine5          Municipi         Comarca  \
# 2190                   2018-12-05  43014.0           Amposta         Montsià
# 2748                   2018-12-05  43065.0            Garcia   Ribera d'Ebre
# 4551                   2018-12-05  25244.0        Vilagrassa          Urgell
# 2260                   2018-12-05  43171.0         Vila-seca      Tarragonès
# 2259                   2018-12-05  25112.0  Ivars de Noguera         Noguera
# ...                           ...      ...               ...             ...
# 1909                   2022-12-15   8217.0   Sant Joan Despí  Baix Llobregat
# 2468                   2022-12-15   8009.0         Argentona         Maresme
# 1349                   2022-12-15  25072.0           Cervera         Segarra
# 2592                   2022-12-15   8121.0            Mataró         Maresme
# 2270                   2022-12-15   8009.0         Argentona         Maresme
#
#      Servei territorial          Vegueria  Província
# 2190   Terres de l'Ebre  Terres de l'Ebre  Tarragona
# 2748   Terres de l'Ebre  Terres de l'Ebre  Tarragona
# 4551             Lleida            Lleida     Lleida
# 2260          Tarragona         Tarragona  Tarragona
# 2259             Lleida            Lleida     Lleida
# ...                 ...               ...        ...
# 1909          Barcelona         Barcelona  Barcelona
# 2468          Barcelona         Barcelona  Barcelona
# 1349             Lleida            Lleida     Lleida
# 2592          Barcelona         Barcelona  Barcelona
# 2270          Barcelona         Barcelona  Barcelona
#
# [2767 rows x 13 columns]

# %% [markdown]
# We are only interested in municipal protection plans (supramunicipal are generic, for whole Catalonia). We do not need the columns num inscr., data homog., ine5., vegueria, servei territorial

# %%
drop_columns = ["Número d'inscripció", "Data d'homologació", "Ine5", "Servei territorial", "Vegueria"]
pam_prot_plans = filt_prot_plans[filt_prot_plans['Província'].notnull()].copy(deep = True).drop(columns = drop_columns).reset_index(drop = True)
pam_prot_plans.rename(columns = {'Comarca':'NOM_COMARCA'}, inplace = True)
pam_prot_plans.head()
# Out:
#   Tipus pla                                        Nom del pla  \
# 0         E                               PAM TRANSCAT Amposta
# 1         E  PA PROCICAT - Emergències Episodis Contaminaci...
# 2         E                             PAM INUNCAT Vilagrassa
# 3         E  PA PROCICAT - Emergències Episodis Contaminaci...
# 4         T                              PBEM Ivars de Noguera
#
#                           Estat Últim esdeveniment  \
# 0  Homologat pendent de revisió        Homologació
# 1  Homologat pendent de revisió        Homologació
# 2  Homologat pendent de revisió        Homologació
# 3  Homologat pendent de revisió        Homologació
# 4  Homologat pendent de revisió        Homologació
#
#   Data de l'últim esdeveniment          Municipi    NOM_COMARCA  Província
# 0                   2018-12-05           Amposta        Montsià  Tarragona
# 1                   2018-12-05            Garcia  Ribera d'Ebre  Tarragona
# 2                   2018-12-05        Vilagrassa         Urgell     Lleida
# 3                   2018-12-05         Vila-seca     Tarragonès  Tarragona
# 4                   2018-12-05  Ivars de Noguera        Noguera     Lleida

# %%
pam_prot_plans["NOM_COMARCA"].unique()
# Out:
# array(['Montsià', "Ribera d'Ebre", 'Urgell', 'Tarragonès', 'Noguera',
#        'Garrigues', 'Baix Empordà', 'Osona', 'Segrià', 'Anoia',
#        'Garrotxa', 'Aran', 'Cerdanya', 'Baix Ebre', 'Alt Camp',
#        'Pallars Sobirà', 'Lluçanès', 'Vallès Oriental',
#        'Vallès Occidental', 'Alt Urgell', 'Berguedà', 'Selva', 'Ripollès',
#        'Baix Camp', 'Conca de Barberà', 'Maresme', "Pla de l'Estany",
#        'Bages', 'Terra Alta', 'Pallars Jussà', 'Gironès', 'Alt Empordà',
#        'Segarra', 'Baix Llobregat', 'Alt Penedès', 'Garraf',
#        'Baix Penedès', 'Priorat', 'Solsonès', 'Barcelonès', 'Moianès'],
#       dtype=object)

# %% [markdown]
# It seems that Alta Ribagorça and Pla d'Urgell do not appear in the data.

# %% [markdown]
# We also need to filter by civil protection plans, since there are plans we are not interested in.

# %%
def filtrar_noms_pla(s):
    lst = s.split(" ")
    if lst[0] == "PAM" and lst[1] == "Pla":
        return "PAM PEEM"
    if lst[0] == "PAM" or lst[0] == "Pam" and lst[1] != "Pla":
        return f"PAM {lst[1]}"
    if lst[0] == "PBEM":
        return "PBEM"
    if lst[0] == "PA":
        return "PA PROCICAT"
    if lst[0] == "PEM":
        return "PEM"
    if lst[0] == "Específic":
        return "Específic"

# %%
pam_prot_plans["Nom del pla"] = pam_prot_plans["Nom del pla"].map(filtrar_noms_pla)

# %%
pam_prot_plans["Nom del pla"].unique()
# Out:
# array(['PAM TRANSCAT', 'PA PROCICAT', 'PAM INUNCAT', 'PBEM',
#        'PAM INFOCAT', 'PAM NEUCAT', 'PAM SISMICAT', 'PAM VENTCAT',
#        'PAM RADCAT', 'PAM PLASEQCAT', 'PAM CAMCAT', 'PAM ALLAUCAT',
#        'PAM AEROCAT', 'PEM', 'Específic', 'PAM PEEM'], dtype=object)

# %% [markdown]
# We have to consider only the plans affecting natural enviroment

# %%
plans_selected = ["PAM INFOCAT","PAM NEUCAT","PAM VENTCAT","PAM SISMICAT","PAM INUNCAT", "PAM ALLAUCAT",
                    "PEM","PAM PEEM","Específic"]
pam_prot_plans = pam_prot_plans[pam_prot_plans["Nom del pla"].isin(plans_selected)]
#he tret PA PROCICAT, perquè és genèric

# %%
pam_prot_plans
# Out:
#      Tipus pla   Nom del pla                         Estat Últim esdeveniment  \
# 2            E   PAM INUNCAT  Homologat pendent de revisió        Homologació
# 5            E   PAM INFOCAT  Homologat pendent de revisió        Homologació
# 7            E    PAM NEUCAT  Homologat pendent de revisió        Homologació
# 9            E  PAM SISMICAT  Homologat pendent de revisió        Homologació
# 10           E    PAM NEUCAT  Homologat pendent de revisió        Homologació
# ...        ...           ...                           ...                ...
# 2758         E   PAM VENTCAT                     Homologat            Revisió
# 2761         E    PAM NEUCAT                     Homologat            Revisió
# 2762         E   PAM INUNCAT                     Homologat        Homologació
# 2765         E  PAM SISMICAT                     Homologat            Revisió
# 2766         E   PAM VENTCAT                     Homologat        Homologació
#
#      Data de l'últim esdeveniment               Municipi     NOM_COMARCA  \
# 2                      2018-12-05             Vilagrassa          Urgell
# 5                      2018-12-05           Palma d'Ebre   Ribera d'Ebre
# 7                      2018-12-05                Palamós    Baix Empordà
# 9                      2018-12-05  Santa Maria de Besora           Osona
# 10                     2018-12-05            Folgueroles           Osona
# ...                           ...                    ...             ...
# 2758                   2022-12-15                 Mataró         Maresme
# 2761                   2022-12-15                 Mataró         Maresme
# 2762                   2022-12-15        Sant Joan Despí  Baix Llobregat
# 2765                   2022-12-15                 Mataró         Maresme
# 2766                   2022-12-15              Argentona         Maresme
#
#       Província
# 2        Lleida
# 5     Tarragona
# 7        Girona
# 9     Barcelona
# 10    Barcelona
# ...         ...
# 2758  Barcelona
# 2761  Barcelona
# 2762  Barcelona
# 2765  Barcelona
# 2766  Barcelona
#
# [1731 rows x 8 columns]

# %% [markdown]
# #### 3.B Homologation, update and revision of PP by county
# What is the total number of actions (homologation, update or revision) of protection plans by county?

# %%
cols = pam_prot_plans.columns.to_list()
cols.remove('Estat')
cols.remove('NOM_COMARCA')

# %%
pam_pp_tot = pam_prot_plans.drop(columns = cols).copy(deep = True).groupby(by = "NOM_COMARCA").count().sort_values(by = 'Estat', ascending = False).reset_index()
pam_pp_tot.replace("Aran", "Val d'Aran", inplace = True) #we need to change from Aran to Val d'Aran

# %%
#We need to add Alta Ribagorça and Pla d'Urgell manually, since it has 0 entries between 2018 and 2022
pam_pp_tot.loc[len(pam_pp_tot.index)] = ["Alta Ribagorça", 0]
pam_pp_tot.loc[len(pam_pp_tot.index)+1] = ["Pla d'Urgell", 0]

# %%
pam_pp_tot.head()
# Out:
#     NOM_COMARCA  Estat
# 0         Osona    138
# 1       Noguera     85
# 2   Alt Penedès     84
# 3         Bages     82
# 4  Baix Empordà     82

# %% [markdown]
# #### 3.C A second geographical plot
# Merge first with catalonia geometry DataFrame

# %%
pam_pp_tot = pam_pp_tot.merge(cat, how='left', on='NOM_COMARCA')
pam_pp_tot_gpd = gpd.GeoDataFrame(pam_pp_tot, geometry="geometry")

# %%
pam_pp_tot_gpd
# Out:
#           NOM_COMARCA  Estat CODICOMAR                 CAPCOMAR  AREAC5000  \
# 0               Osona    138        24                      Vic  1246.9802
# 1             Noguera     85        23                 Balaguer  1783.3727
# 2         Alt Penedès     84        03   Vilafranca del Penedès   592.5498
# 3               Bages     82        07                  Manresa  1092.7982
# 4        Baix Empordà     82        10      la Bisbal d'Empordà   701.1353
# 5             Segarra     77        32                  Cervera   723.5756
# 6         Alt Empordà     68        02                 Figueres  1356.6431
# 7               Selva     61        34  Santa Coloma de Farners   994.0428
# 8      Baix Llobregat     61        11  Sant Feliu de Llobregat   487.4743
# 9            Berguedà     58        14                    Berga  1185.2257
# 10            Maresme     47        21                   Mataró   397.9019
# 11         Alt Urgell     44        04          la Seu d'Urgell  1447.2028
# 12  Vallès Occidental     44        40      Sabadell / Terrassa   583.0649
# 13              Anoia     43        06                 Igualada   867.0471
# 14          Garrigues     42        18      les Borges Blanques   797.2156
# 15         Tarragonès     39        36                Tarragona   320.5849
# 16    Vallès Oriental     38        41               Granollers   735.2397
# 17            Moianès     37        42                     Moià   337.2896
# 18       Baix Penedès     36        12              el Vendrell   296.4311
# 19           Ripollès     35        31                   Ripoll   956.8939
# 20      Pallars Jussà     35        25                    Tremp  1343.5020
# 21          Baix Camp     34        08                     Reus   696.4883
# 22             Urgell     33        38                  Tàrrega   578.2949
# 23             Segrià     32        33                   Lleida  1396.1161
# 24           Solsonès     31        35                  Solsona  1000.2169
# 25           Alt Camp     30        01                    Valls   537.6317
# 26      Ribera d'Ebre     29        30              Móra d'Ebre   827.6182
# 27            Gironès     29        20                   Girona   575.9353
# 28            Priorat     27        29                   Falset   498.0777
# 29          Baix Ebre     26        09                  Tortosa  1001.9306
# 30         Terra Alta     24        37                  Gandesa   742.6641
# 31         Val d'Aran     24        39                   Vielha   632.9978
# 32           Lluçanès     24       NaN                      NaN        NaN
# 33    Pla de l'Estany     23        28                 Banyoles   263.3198
# 34           Garrotxa     23        19                     Olot   733.3229
# 35   Conca de Barberà     23        16                Montblanc   650.6021
# 36            Montsià     20        22                  Amposta   733.6485
# 37     Pallars Sobirà     18        26                     Sort  1378.2154
# 38           Cerdanya     17        15                Puigcerdà   546.4545
# 39             Garraf     14        17     Vilanova i la Geltrú   185.2434
# 40         Barcelonès     14        13                Barcelona   146.3935
# 41     Alta Ribagorça      0        05         el Pont de Suert   427.2234
# 42       Pla d'Urgell      0        27               Mollerussa   305.4285
#
#                                              geometry
# 0   MULTIPOLYGON (((418580.652 4643167.275, 418307...
# 1   POLYGON ((348524.976 4664596.302, 348400.341 4...
# 2   POLYGON ((385914.163 4595999.962, 386085.364 4...
# 3   POLYGON ((417259.067 4646530.811, 417513.903 4...
# 4   MULTIPOLYGON (((497966.430 4622427.830, 497965...
# 5   POLYGON ((365993.100 4642951.900, 366072.200 4...
# 6   MULTIPOLYGON (((514495.140 4662167.740, 514492...
# 7   MULTIPOLYGON (((482690.024 4613155.364, 482688...
# 8   POLYGON ((401068.400 4606276.800, 401178.618 4...
# 9   MULTIPOLYGON (((391614.800 4661923.500, 391606...
# 10  POLYGON ((477054.900 4621435.100, 478728.500 4...
# 11  MULTIPOLYGON (((360736.000 4649167.000, 360624...
# 12  POLYGON ((426549.300 4618464.000, 427202.000 4...
# 13  POLYGON ((370158.839 4628885.052, 370282.509 4...
# 14  POLYGON ((327888.707 4605730.867, 328155.807 4...
# 15  MULTIPOLYGON (((363274.620 4554494.750, 363220...
# 16  POLYGON ((449099.721 4628266.206, 449108.947 4...
# 17  POLYGON ((428837.859 4639478.022, 428961.755 4...
# 18  MULTIPOLYGON (((384508.440 4560878.000, 384505...
# 19  MULTIPOLYGON (((419785.996 4664417.149, 419923...
# 20  MULTIPOLYGON (((317718.105 4693389.714, 317738...
# 21  MULTIPOLYGON (((335052.970 4547018.980, 335051...
# 22  MULTIPOLYGON (((330423.400 4623950.100, 329861...
# 23  MULTIPOLYGON (((316312.768 4606506.701, 315561...
# 24  MULTIPOLYGON (((393371.457 4638570.630, 393374...
# 25  POLYGON ((373635.755 4592021.079, 373669.333 4...
# 26  POLYGON ((288368.413 4578209.165, 288383.230 4...
# 27  POLYGON ((494081.526 4662565.750, 494214.686 4...
# 28  POLYGON ((320525.200 4579659.500, 321213.700 4...
# 29  MULTIPOLYGON (((311847.200 4514855.880, 311833...
# 30  POLYGON ((280206.273 4568311.294, 280325.826 4...
# 31  POLYGON ((313407.046 4747612.147, 313430.255 4...
# 32                                               None
# 33  POLYGON ((482120.535 4672805.481, 482191.594 4...
# 34  POLYGON ((462306.492 4686925.593, 462315.342 4...
# 35  POLYGON ((369548.800 4603947.800, 370045.800 4...
# 36  MULTIPOLYGON (((298299.980 4494128.520, 298299...
# 37  POLYGON ((343217.247 4738499.818, 343225.151 4...
# 38  MULTIPOLYGON (((417240.539 4704752.127, 417684...
# 39  MULTIPOLYGON (((386888.695 4561204.584, 386881...
# 40  MULTIPOLYGON (((430106.350 4576516.340, 430098...
# 41  POLYGON ((326572.730 4721574.001, 326622.339 4...
# 42  MULTIPOLYGON (((341924.700 4618515.800, 341260...

# %% [markdown]
# Notice that entries for Lluçanès must be errors, since we have that Lluçanès has been officialized as a county in 2023, and we already filtered data between 2018 and 2022. This must be they have modified the county of some of the CPP to the municipalities corresponding to the actual Lluçanès.

# %%
#highlight the counties with most mod CPP legal status actions
colors2 = {"Osona":'darkorange',
          "Alt Penedès":'palegreen',
          "Bages":'mediumorchid',
          "Noguera":'gold',
          "Segarra":'darkred'}

fig, ax = plt.subplots(1,1,figsize=(6,4))
ax.set_xticks([])
ax.set_yticks([])
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('none')
norm = LogNorm()
# plt.rc('text', usetex = True)
# plt.rc('font', family='serif')
plot = pam_pp_tot_gpd.plot(column = 'Estat',
                                  ax=ax,
                                  legend=False,
                                  cmap='Blues',
                                  norm = norm,
                                  legend_kwds={'orientation': "horizontal", 'pad': 0.2})
pam_pp_tot_gpd.boundary.plot(ax = ax, linewidth = 0.2, color = 'black')
pam_pp_tot_gpd = pam_pp_tot_gpd.set_index("NOM_COMARCA")
pam_pp_tot_gpd.loc[list(colors2.keys()),:].boundary.plot(ax=ax,color=list(colors2.values()), linewidth = 1.5)
pam_pp_tot_gpd = pam_pp_tot_gpd.reset_index()
cbar = fig.colorbar(plot.get_children()[0], ax = ax, label = r'num. mod. CPP 2018-2022')
cb_ax = fig.axes[1] 
# cb_ax.tick_params(labelsize=10)
plt.savefig('figures/total_CPP_num_2018_2022.pdf')
plt.show()

# %% [markdown]
# ### 4. Map panel

# %%
# Create a 1x2 subplot grid
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Plot the first set of data (rescue actions)
ax1 = axes[0]
ax1.set_xticks([])
ax1.set_yticks([])
ax1.spines['top'].set_color('none')
ax1.spines['bottom'].set_color('none')
ax1.spines['right'].set_color('none')
ax1.spines['left'].set_color('none')
norm1 = LogNorm()

plot1 = merged_rescue_tot_gpd.plot(column='ACT_NUM_ACTUACIO',
                                    ax=ax1,
                                    legend=False,
                                    cmap='Blues',
                                    norm=norm1,
                                    legend_kwds={'orientation': "horizontal", 'pad': 0.2})
merged_rescue_tot_gpd.boundary.plot(ax=ax1, linewidth=0.2, color='black')
merged_rescue_tot_gpd = merged_rescue_tot_gpd.set_index("NOM_COMARCA")
merged_rescue_tot_gpd.loc[list(colors.keys()), :].boundary.plot(ax=ax1, color=list(colors.values()), linewidth=1.5)
merged_rescue_tot_gpd = merged_rescue_tot_gpd.reset_index()
cbar1 = fig.colorbar(plot1.get_children()[0], ax=ax1, label=r'Num. rescue actions 2018-2022')
cb_ax1 = fig.axes[1]

# Add legend for highlighted counties in the first map
for county, color in colors.items():
    ax1.plot([], [], color=color, label=county, linewidth=1.5)

# Plot the second set of data (CPP modifications)
ax2 = axes[1]
ax2.set_xticks([])
ax2.set_yticks([])
ax2.spines['top'].set_color('none')
ax2.spines['bottom'].set_color('none')
ax2.spines['right'].set_color('none')
ax2.spines['left'].set_color('none')
norm2 = LogNorm()

plot2 = pam_pp_tot_gpd.plot(column='Estat',
                             ax=ax2,
                             legend=False,
                             cmap='Blues',
                             norm=norm2,
                             legend_kwds={'orientation': "horizontal", 'pad': 0.2})
pam_pp_tot_gpd.boundary.plot(ax=ax2, linewidth=0.2, color='black')
pam_pp_tot_gpd = pam_pp_tot_gpd.set_index("NOM_COMARCA")
pam_pp_tot_gpd.loc[list(colors2.keys()), :].boundary.plot(ax=ax2, color=list(colors2.values()), linewidth=1.5)
pam_pp_tot_gpd = pam_pp_tot_gpd.reset_index()
cbar2 = fig.colorbar(plot2.get_children()[0], ax=ax2, label=r'Num. mod. CPP 2018-2022')
cb_ax2 = fig.axes[1]

# Add legend for highlighted counties in the second map
for county, color in colors2.items():
    ax2.plot([], [], color=color, label=county, linewidth=1.5)
    
# Add individual legends for each map with reduced size and at lower left
ax1.legend(loc='lower right', fontsize='small')
ax2.legend(loc='lower right', fontsize='small')

# Adjust layout to prevent overlap
plt.tight_layout()

# Save or show the figure
plt.savefig('figures/merged_maps_plot.pdf')
plt.show()

# %% [markdown]
# ### 5. Rescue/ CPP study of Osona

# %% [markdown]
# #### 5.A Rescue actions study of Osona

# %%
columns = filt_rescues.columns.to_list()
#remove the coloms we need to keep
columns.remove('GEOREFERÈNCIA')
columns.remove('LATITUD')
columns.remove('LONGITUD')
columns.remove('ANY')
columns.remove('MUNICIPI')
columns.remove('TAL_NOM_ALARMA')
columns.remove('TAL_COD_ALARMA2')

# %%
resc_filt_os = filt_rescues[filt_rescues["NOM_COMARCA"] == "Osona"].drop(columns = columns).copy(deep = True)

# %%
resc_filt_os.head()
# Out:
#      TAL_COD_ALARMA2                             TAL_NOM_ALARMA  \
# 1819              MU           Salvament i/o rescat de muntanya
# 1837              MU           Salvament i/o rescat de muntanya
# 1883              RC  Recerca persones perdudes o desaparegudes
# 1892              MU           Salvament i/o rescat de muntanya
# 1911              MU           Salvament i/o rescat de muntanya
#
#                    MUNICIPI   ANY  LONGITUD    LATITUD  \
# 1819             Muntanyola  2022  2.127187  41.929779
# 1837        Vilanova de Sau  2022  2.429212  41.920734
# 1883               Tavertet  2022  2.403446  41.992594
# 1892  Santa Maria de Besora  2022  2.245424  42.123915
# 1911          Rupit i Pruit  2022  2.474646  41.995103
#
#                                GEOREFERÈNCIA
# 1819  POINT (2.127187229202 41.929778661215)
# 1837  POINT (2.429212124473 41.920734154401)
# 1883  POINT (2.403446087266 41.992593601088)
# 1892  POINT (2.245423824424 42.123915004894)
# 1911  POINT (2.474645629342 41.995103116441)

# %% [markdown]
# What are the types of rescue actions carried out?

# %%
resc_filt_os["TAL_COD_ALARMA2"].unique()
# Out:
# array(['MU', 'RC', 'FL'], dtype=object)

# %%
resc_filt_os["TAL_COD_ALARMA2"].unique()[0]
# Out:
# 'MU'

# %%
resc_filt_os[resc_filt_os["TAL_COD_ALARMA2"] == resc_filt_os["TAL_COD_ALARMA2"].unique()[0]].iloc[0]["TAL_NOM_ALARMA"]
# Out:
# 'Salvament i/o rescat de muntanya'

# %%
codis_tipus = {}
for i in resc_filt_os["TAL_COD_ALARMA2"].unique():
    codis_tipus[i] = resc_filt_os[resc_filt_os["TAL_COD_ALARMA2"] == i].iloc[0]["TAL_NOM_ALARMA"]
print(codis_tipus)
# Out:
# {'MU': 'Salvament i/o rescat de muntanya', 'RC': 'Recerca persones perdudes o desaparegudes', 'FL': 'Salvament i/o recerca i/o rescat en medi fluvial (rius,barrancs, llacs)'}

# %% [markdown]
# Salvament i/o recerca i/o rescat en medi fluvial (rius,barrancs, llacs) is too long for a description, let us omit (rius, barrancs, llacs)

# %%
codis_tipus["FL"] = codis_tipus["FL"].replace(" (rius,barrancs, llacs)", "")
print(codis_tipus["FL"])
# Out:
# Salvament i/o recerca i/o rescat en medi fluvial

# %% [markdown]
# Make new DataFrame with information separated by year and type of rescue action

# %%
grouped_by_years_os = resc_filt_os.groupby(by = ["ANY", "TAL_COD_ALARMA2"]).count().drop(columns = ["LONGITUD", "LATITUD", "GEOREFERÈNCIA"])
grouped_by_years_os.drop(columns = ['TAL_NOM_ALARMA'], inplace = True)
grouped_by_years_os.rename(columns = {'MUNICIPI':'NUM_ACTIONS'}, inplace = True)
grouped_by_years_os.head()
# Out:
#                       NUM_ACTIONS
# ANY  TAL_COD_ALARMA2
# 2018 FL                         4
#      MU                        30
#      RC                        23
# 2019 MU                        29
#      RC                        11

# %%
# Map 'TAL_COD_ALARMA2' values to descriptions using codis_tipus dictionary
grouped_by_years_os.reset_index(level = 'TAL_COD_ALARMA2', inplace = True)
grouped_by_years_os['TAL_COD_ALARMA2_DESC'] = grouped_by_years_os['TAL_COD_ALARMA2'].map(codis_tipus)
grouped_by_years_os.head()
# Out:
#      TAL_COD_ALARMA2  NUM_ACTIONS  \
# ANY
# 2018              FL            4
# 2018              MU           30
# 2018              RC           23
# 2019              MU           29
# 2019              RC           11
#
#                                   TAL_COD_ALARMA2_DESC
# ANY
# 2018  Salvament i/o recerca i/o rescat en medi fluvial
# 2018                  Salvament i/o rescat de muntanya
# 2018         Recerca persones perdudes o desaparegudes
# 2019                  Salvament i/o rescat de muntanya
# 2019         Recerca persones perdudes o desaparegudes

# %%
# Create a bar plot. Use a colorblind palette to represent categorical data.
plt.figure(figsize=(6, 4))
colors = ["#0fb5ae", "#4046ca", "#f68511", "#de3d82", "#7e84fa"]
customPalette = sns.set_palette(sns.color_palette(colors))
sns.barplot(x='ANY', y='NUM_ACTIONS', hue='TAL_COD_ALARMA2', data=grouped_by_years_os, palette = customPalette, saturation = 1, width = 0.9)

# Set plot labels and title
plt.xlabel('year')
plt.ylabel('num. rescues')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Save and show the plot
plt.tight_layout()
plt.savefig("figures/rescue_osona.pdf")
plt.show()

# %% [markdown]
# #### 5.B CPP action in Osona

# %% [markdown]
# The CPP have already been filtered in the time window we are interested in. We only need to grab those entries with county Osona and drop innecessary columns

# %% [markdown]
# We are going to study the protection plans with modifications/updates/revisions in the year 2021, since we noticed a big peak of rescue actions

# %%
pam_prot_plans_os = pam_prot_plans[pam_prot_plans["NOM_COMARCA"] == "Osona"].copy().reset_index(drop = True)

# %%
pam_prot_plans_os
# Out:
#     Tipus pla   Nom del pla                         Estat Últim esdeveniment  \
# 0           E  PAM SISMICAT  Homologat pendent de revisió        Homologació
# 1           E    PAM NEUCAT  Homologat pendent de revisió        Homologació
# 2           E  PAM SISMICAT  Homologat pendent de revisió        Homologació
# 3           E  PAM SISMICAT  Homologat pendent de revisió        Homologació
# 4           E    PAM NEUCAT  Homologat pendent de revisió        Homologació
# ..        ...           ...                           ...                ...
# 133         E   PAM INUNCAT                     Homologat        Homologació
# 134         E   PAM INFOCAT                     Homologat        Homologació
# 135         E  PAM SISMICAT                     Homologat        Homologació
# 136         E   PAM VENTCAT                     Homologat        Homologació
# 137         E    PAM NEUCAT                     Homologat        Homologació
#
#     Data de l'últim esdeveniment                Municipi NOM_COMARCA  \
# 0                     2018-12-05   Santa Maria de Besora       Osona
# 1                     2018-12-05             Folgueroles       Osona
# 2                     2018-12-05         Vilanova de Sau       Osona
# 3                     2018-12-05                   Brull       Osona
# 4                     2018-12-05  Santa Eugènia de Berga       Osona
# ..                           ...                     ...         ...
# 133                   2022-12-15                    Seva       Osona
# 134                   2022-12-15                    Seva       Osona
# 135                   2022-12-15                    Seva       Osona
# 136                   2022-12-15                    Seva       Osona
# 137                   2022-12-15                    Seva       Osona
#
#      Província
# 0    Barcelona
# 1    Barcelona
# 2    Barcelona
# 3    Barcelona
# 4    Barcelona
# ..         ...
# 133  Barcelona
# 134  Barcelona
# 135  Barcelona
# 136  Barcelona
# 137  Barcelona
#
# [138 rows x 8 columns]

# %%
pam_prot_plans_os["Nom del pla"].unique()
# Out:
# array(['PAM SISMICAT', 'PAM NEUCAT', 'PAM INFOCAT', 'PAM VENTCAT',
#        'PAM INUNCAT'], dtype=object)

# %% [markdown]
# We need to create a year column

# %%
pam_prot_plans_os["ANY"] = pam_prot_plans_os["Data de l'últim esdeveniment"].dt.year

# %%
pam_prot_plans_os.head()
# Out:
#   Tipus pla   Nom del pla                         Estat Últim esdeveniment  \
# 0         E  PAM SISMICAT  Homologat pendent de revisió        Homologació
# 1         E    PAM NEUCAT  Homologat pendent de revisió        Homologació
# 2         E  PAM SISMICAT  Homologat pendent de revisió        Homologació
# 3         E  PAM SISMICAT  Homologat pendent de revisió        Homologació
# 4         E    PAM NEUCAT  Homologat pendent de revisió        Homologació
#
#   Data de l'últim esdeveniment                Municipi NOM_COMARCA  Província  \
# 0                   2018-12-05   Santa Maria de Besora       Osona  Barcelona
# 1                   2018-12-05             Folgueroles       Osona  Barcelona
# 2                   2018-12-05         Vilanova de Sau       Osona  Barcelona
# 3                   2018-12-05                   Brull       Osona  Barcelona
# 4                   2018-12-05  Santa Eugènia de Berga       Osona  Barcelona
#
#     ANY
# 0  2018
# 1  2018
# 2  2018
# 3  2018
# 4  2018

# %%
grouped_by_years_ccp_os = pam_prot_plans_os.groupby(by = ["ANY", "Nom del pla"]).count().drop(columns = ["Tipus pla", "Últim esdeveniment", "Data de l'últim esdeveniment", "Municipi", "NOM_COMARCA", "Província"])

# %%
grouped_by_years_ccp_os
# Out:
#                    Estat
# ANY  Nom del pla
# 2018 PAM INFOCAT       8
#      PAM INUNCAT       8
#      PAM NEUCAT       12
#      PAM SISMICAT     12
#      PAM VENTCAT       4
# 2019 PAM INFOCAT       7
#      PAM INUNCAT       3
#      PAM NEUCAT        8
#      PAM SISMICAT      8
#      PAM VENTCAT       2
# 2020 PAM INFOCAT       9
#      PAM INUNCAT       6
#      PAM NEUCAT       11
#      PAM SISMICAT     11
#      PAM VENTCAT       5
# 2021 PAM INFOCAT       3
#      PAM INUNCAT       1
#      PAM NEUCAT        4
#      PAM SISMICAT      4
#      PAM VENTCAT       3
# 2022 PAM INFOCAT       2
#      PAM INUNCAT       1
#      PAM NEUCAT        2
#      PAM SISMICAT      2
#      PAM VENTCAT       2

# %%
# Create a bar plot. Use a colorblind palette to represent categorical data.
plt.figure(figsize=(8, 4))
hue_order = ["PAM INFOCAT", "PAM INUNCAT", "PAM NEUCAT", "PAM SISMICAT", "PAM VENTCAT"]
alternative_palette = ["#4689ff", "#d02770", "#d3a107", "#09bdb9", "#bbe6fe"]
customPalette = sns.set_palette(sns.color_palette(alternative_palette))
sns.barplot(x='ANY', y='Estat', hue='Nom del pla', data=grouped_by_years_ccp_os, hue_order = hue_order,palette = customPalette, saturation = 1, width = 0.7)

# Set plot labels and title
plt.xlabel('year')
plt.ylabel('num. mod. CPP')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Save and show the plot
plt.tight_layout()
plt.savefig("figures/cpp_osona.pdf")
plt.show()

# %% [markdown]
# #### 5.C Osona rescue/CPP action panel

# %%
# Set the colorblind palette
colorblind_palette = ["#0fb5ae", "#4046ca", "#f68511"]

# Set the alternative palette
alternative_palette = ["#4689ff", "#d02770", "#d3a107", "#09bdb9", "#bbe6fe"]

#Order palette
hue_order = ["FL", "MU", "RC"]
hue_order_2 = ["PAM INFOCAT", "PAM INUNCAT", "PAM NEUCAT", "PAM SISMICAT", "PAM VENTCAT"]
# Create subplots with 2 rows and 1 column
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8, 8))

# First subplot (top)
sns.barplot(x='ANY', y='NUM_ACTIONS', hue='TAL_COD_ALARMA2', data=grouped_by_years_os, hue_order = hue_order, palette=colorblind_palette, saturation=1, width=0.7, ax=axes[0])

axes[0].set_xlabel('Year')
axes[0].set_ylabel('Num. rescues')
axes[0].legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Second subplot (bottom)
sns.barplot(x='ANY', y='Estat', hue='Nom del pla', data=grouped_by_years_ccp_os, hue_order = hue_order_2,palette=alternative_palette, saturation=1, width=0.7, ax=axes[1])

axes[1].set_xlabel('Year')
axes[1].set_ylabel('Num. mod. CPP')
axes[1].legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Add a title to the entire figure
plt.suptitle('Osona', fontsize=12)

# Adjust layout and save the plot
plt.tight_layout()
plt.savefig("figures/combined_plot_osona.pdf")
plt.show()

# %% [markdown]
# ### 6. Rescue/ CPP study of Baix Llobregat

# %% [markdown]
# #### 6.A Rescue actions study of Baix Llobregat
# We will proceed similarly as we have done in the case of Osona

# %%
resc_filt_bl = filt_rescues[filt_rescues["NOM_COMARCA"] == "Baix Llobregat"].drop(columns = columns).copy(deep = True)

# %%
resc_filt_bl
# Out:
#       TAL_COD_ALARMA2                                     TAL_NOM_ALARMA  \
# 1803               RC          Recerca persones perdudes o desaparegudes
# 1838               MU                   Salvament i/o rescat de muntanya
# 1846               MU                   Salvament i/o rescat de muntanya
# 1850               MU                   Salvament i/o rescat de muntanya
# 1871               MU                   Salvament i/o rescat de muntanya
# ...               ...                                                ...
# 10174              MU                                 Rescat de muntanya
# 10190              RC                          Recerca persones perdudes
# 10214              FL  Recerca i/o rescat en medi fluvial (rius, barr...
# 10222              RC                          Recerca persones perdudes
# 10230              RC                          Recerca persones perdudes
#
#                        MUNICIPI   ANY  LONGITUD    LATITUD  \
# 1803                   Cervelló  2022  1.968336  41.389724
# 1838                   Collbató  2022  1.817894  41.585364
# 1846                 Papiol, El  2022       NaN        NaN
# 1850              Molins de Rei  2022  2.060471  41.437883
# 1871                   Cervelló  2022  1.929912  41.407613
# ...                         ...   ...       ...        ...
# 10174             Molins de Rei  2018  2.077893  41.412137
# 10190                  Collbató  2018  1.828212  41.569401
# 10214     Cornellà de Llobregat  2018  2.059436  41.348674
# 10222                  Collbató  2018  1.841238  41.574721
# 10230  Santa Coloma de Cervelló  2018       NaN        NaN
#
#                                 GEOREFERÈNCIA
# 1803   POINT (1.968336482849 41.389723633915)
# 1838   POINT (1.817894209259 41.585363674964)
# 1846                                      NaN
# 1850   POINT (2.060471253494 41.437882960729)
# 1871   POINT (1.929911825334 41.407612697399)
# ...                                       ...
# 10174                                     NaN
# 10190                                     NaN
# 10214                                     NaN
# 10222                                     NaN
# 10230                                     NaN
#
# [527 rows x 7 columns]

# %% [markdown]
# New dataframe grouped by year and alarm code

# %%
grouped_by_years_bl = resc_filt_bl.groupby(by = ["ANY", "TAL_COD_ALARMA2"]).count().drop(columns = ["LONGITUD", "LATITUD", "GEOREFERÈNCIA"])
grouped_by_years_bl.drop(columns = ['TAL_NOM_ALARMA'], inplace = True)
grouped_by_years_bl.rename(columns = {'MUNICIPI':'NUM_ACTIONS'}, inplace = True)
grouped_by_years_bl
# Out:
#                       NUM_ACTIONS
# ANY  TAL_COD_ALARMA2
# 2018 FL                         4
#      MR                         6
#      MU                        48
#      RC                        26
# 2019 CO                         1
#      FL                         6
#      MR                         3
#      MU                        63
#      RC                        26
# 2020 CO                         1
#      FL                         2
#      MR                         8
#      MU                        64
#      RC                        24
# 2021 FL                         3
#      MR                         7
#      MU                        99
#      RC                        26
# 2022 CO                         1
#      FL                         5
#      MR                         8
#      MU                        70
#      RC                        26

# %% [markdown]
# We will also make a bar plot for the total number of rescue operations by year and hued by the typology for the Baix Llobregat

# %%
# Create a bar plot. Use a colorblind palette to represent categorical data.
plt.figure(figsize=(8, 4))
hue_order = ["FL", "MU", "RC", "MR", "CO"]
colors = ["#0fb5ae", "#4046ca", "#f68511", "#de3d82", "#7e84fa"]
customPalette = sns.set_palette(sns.color_palette(colors))
sns.barplot(x='ANY', y='NUM_ACTIONS', hue='TAL_COD_ALARMA2', hue_order = hue_order, data=grouped_by_years_bl, palette = customPalette, saturation = 1, width = 0.9)

# Set plot labels and title
plt.xlabel('year')
plt.ylabel('num. rescues')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Save and show the plot
plt.tight_layout()
plt.savefig("figures/rescue_baix_llobregat.pdf")
plt.show()

# %% [markdown]
# #### 6.B CPP action in Baix Llobregat
# We proceed similarly as we have done for the case of Osona

# %%
pam_prot_plans_bl = pam_prot_plans[pam_prot_plans["NOM_COMARCA"] == "Baix Llobregat"].copy().reset_index(drop = True)

# %%
pam_prot_plans_bl
# Out:
#    Tipus pla   Nom del pla                         Estat Últim esdeveniment  \
# 0          E   PAM VENTCAT  Homologat pendent de revisió        Homologació
# 1          E    PAM NEUCAT  Homologat pendent de revisió        Homologació
# 2          E   PAM INUNCAT  Homologat pendent de revisió        Homologació
# 3          E   PAM INFOCAT  Homologat pendent de revisió        Homologació
# 4          E   PAM INUNCAT                     Homologat        Homologació
# ..       ...           ...                           ...                ...
# 56         E   PAM VENTCAT                     Homologat        Homologació
# 57         E  PAM SISMICAT                     Homologat        Homologació
# 58         E   PAM VENTCAT                     Homologat        Homologació
# 59         E    PAM NEUCAT                     Homologat        Homologació
# 60         E   PAM INUNCAT                     Homologat        Homologació
#
#    Data de l'últim esdeveniment                Municipi     NOM_COMARCA  \
# 0                    2019-03-21  Sant Esteve Sesrovires  Baix Llobregat
# 1                    2019-03-21  Sant Esteve Sesrovires  Baix Llobregat
# 2                    2019-03-21  Sant Esteve Sesrovires  Baix Llobregat
# 3                    2019-03-21  Sant Esteve Sesrovires  Baix Llobregat
# 4                    2020-10-30       Prat de Llobregat  Baix Llobregat
# ..                          ...                     ...             ...
# 56                   2022-10-06              Viladecans  Baix Llobregat
# 57                   2022-12-15         Sant Joan Despí  Baix Llobregat
# 58                   2022-12-15         Sant Joan Despí  Baix Llobregat
# 59                   2022-12-15         Sant Joan Despí  Baix Llobregat
# 60                   2022-12-15         Sant Joan Despí  Baix Llobregat
#
#     Província
# 0   Barcelona
# 1   Barcelona
# 2   Barcelona
# 3   Barcelona
# 4   Barcelona
# ..        ...
# 56  Barcelona
# 57  Barcelona
# 58  Barcelona
# 59  Barcelona
# 60  Barcelona
#
# [61 rows x 8 columns]

# %% [markdown]
# What CCP plans have been homologated/revised/updated?

# %%
pam_prot_plans_bl["Nom del pla"].unique()
# Out:
# array(['PAM VENTCAT', 'PAM NEUCAT', 'PAM INUNCAT', 'PAM INFOCAT',
#        'PAM SISMICAT'], dtype=object)

# %% [markdown]
# Create year columns

# %%
pam_prot_plans_bl["ANY"] = pam_prot_plans_bl["Data de l'últim esdeveniment"].dt.year

# %%
grouped_by_years_ccp_bl = pam_prot_plans_bl.groupby(by = ["ANY", "Nom del pla"]).count().drop(columns = ["Tipus pla", "Últim esdeveniment", "Data de l'últim esdeveniment", "Municipi", "NOM_COMARCA", "Província"])
grouped_by_years_ccp_bl
# Out:
#                    Estat
# ANY  Nom del pla
# 2019 PAM INFOCAT       1
#      PAM INUNCAT       1
#      PAM NEUCAT        1
#      PAM VENTCAT       1
# 2020 PAM INFOCAT       1
#      PAM INUNCAT       1
#      PAM NEUCAT        1
#      PAM SISMICAT      1
#      PAM VENTCAT       1
# 2021 PAM INFOCAT       7
#      PAM INUNCAT       7
#      PAM NEUCAT        7
#      PAM SISMICAT      7
#      PAM VENTCAT       5
# 2022 PAM INFOCAT       3
#      PAM INUNCAT       4
#      PAM NEUCAT        4
#      PAM SISMICAT      4
#      PAM VENTCAT       4

# %%
# Create a bar plot. Use a colorblind palette to represent categorical data.
plt.figure(figsize=(8, 4))
hue_order = ["PAM INFOCAT", "PAM INUNCAT", "PAM NEUCAT", "PAM SISMICAT", "PAM VENTCAT"]
alternative_palette = ["#4689ff", "#d02770", "#d3a107", "#09bdb9", "#bbe6fe"]
customPalette = sns.set_palette(sns.color_palette(alternative_palette))
sns.barplot(x='ANY', y='Estat', hue='Nom del pla', data=grouped_by_years_ccp_bl, hue_order = hue_order ,palette = customPalette, saturation = 1, width = 0.7)

# Set plot labels and title
plt.xlabel('year')
plt.ylabel('num. mod. CPP')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Save and show the plot
plt.tight_layout()
plt.savefig("figures/cpp_baix_llobregat.pdf")
plt.show()

# %% [markdown]
# #### 6.C Baix Llobregat rescue/CPP action panel

# %%
# Set the colorblind palette
colorblind_palette = ["#0fb5ae", "#4046ca", "#f68511", "#de3d82", "#7e84fa"]

# Set the alternative palette
alternative_palette = ["#4689ff", "#d02770", "#d3a107", "#09bdb9", "#bbe6fe"]

hue_order = ["FL", "MU", "RC", "MR", "CO"]
hue_order_2 = ["PAM INFOCAT", "PAM INUNCAT", "PAM NEUCAT", "PAM SISMICAT", "PAM VENTCAT"]
# Create subplots with 2 rows and 1 column
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8, 8))

# First subplot (top)
sns.barplot(x='ANY', y='NUM_ACTIONS', hue='TAL_COD_ALARMA2', hue_order=hue_order, data=grouped_by_years_bl, palette=colorblind_palette, saturation=1, width=0.9, ax=axes[0])

axes[0].set_xlabel('Year')
axes[0].set_ylabel('Num. rescues')
axes[0].legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Second subplot (bottom)
sns.barplot(x='ANY', y='Estat', hue='Nom del pla', data=grouped_by_years_ccp_bl, hue_order = hue_order_2,palette=alternative_palette, saturation=1, width=0.7, ax=axes[1])

axes[1].set_xlabel('Year')
axes[1].set_ylabel('Num. mod. CPP')
axes[1].legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Add a title to the entire figure
plt.suptitle('Baix Llobregat', fontsize=12)

# Adjust layout and save the plot
plt.tight_layout()
plt.savefig("figures/combined_plot_baix_llobregat.pdf")
plt.show()

# %% [markdown]
# ### 7. Rescue/ CPP study of Val d'Aran

# %% [markdown]
# #### 7.A Rescue actions study of Val d'Aran
# We will proceed similarly as we have done in the preivous cases

# %%
resc_filt_va = filt_rescues[filt_rescues["NOM_COMARCA"] == "Val d'Aran"].drop(columns = columns).copy(deep = True)

# %%
resc_filt_va
# Out:
#       TAL_COD_ALARMA2                    TAL_NOM_ALARMA          MUNICIPI  \
# 1797               MU  Salvament i/o rescat de muntanya         Naut Aran
# 1806               MU  Salvament i/o rescat de muntanya         Naut Aran
# 1808               MU  Salvament i/o rescat de muntanya  Vielha e Mijaran
# 1823               MU  Salvament i/o rescat de muntanya         Naut Aran
# 1824               MU  Salvament i/o rescat de muntanya         Naut Aran
# ...               ...                               ...               ...
# 10189              RC         Recerca persones perdudes  Vielha e Mijaran
# 10200              MU                Rescat de muntanya  Vielha e Mijaran
# 10207              MU                Rescat de muntanya         Naut Aran
# 10215              MU                Rescat de muntanya         Naut Aran
# 10226              MU                Rescat de muntanya         Naut Aran
#
#         ANY  LONGITUD    LATITUD                           GEOREFERÈNCIA
# 1797   2022  0.993092  42.670455  POINT (0.993092440136 42.670455109079)
# 1806   2022  0.963995  42.732617  POINT (0.963995209895 42.732616911909)
# 1808   2022  0.747175  42.631004  POINT (0.747175447428 42.631004146557)
# 1823   2022  0.946063  42.703381  POINT (0.946063112774 42.703381338418)
# 1824   2022  0.946260  42.699999  POINT (0.946260107866 42.699998958951)
# ...     ...       ...        ...                                     ...
# 10189  2018  0.800557  42.721543                                     NaN
# 10200  2018  0.716576  42.638377                                     NaN
# 10207  2018       NaN        NaN                                     NaN
# 10215  2018       NaN        NaN                                     NaN
# 10226  2018       NaN        NaN                                     NaN
#
# [500 rows x 7 columns]

# %% [markdown]
# New dataframe grouped by year and alarm code

# %%
grouped_by_years_va = resc_filt_va.groupby(by = ["ANY", "TAL_COD_ALARMA2"]).count().drop(columns = ["LONGITUD", "LATITUD", "GEOREFERÈNCIA"])
grouped_by_years_va.drop(columns = ['TAL_NOM_ALARMA'], inplace = True)
grouped_by_years_va.rename(columns = {'MUNICIPI':'NUM_ACTIONS'}, inplace = True)
grouped_by_years_va
# Out:
#                       NUM_ACTIONS
# ANY  TAL_COD_ALARMA2
# 2018 CO                         1
#      FL                         1
#      MU                        72
#      RC                        20
# 2019 FL                         1
#      MU                        75
#      RC                        16
# 2020 FL                         2
#      MU                        68
#      RC                        20
# 2021 FL                         2
#      MU                        85
#      RC                        15
# 2022 CO                         1
#      MU                       106
#      RC                        15

# %% [markdown]
# We will also make a bar plot for the total number of rescue operations by year and hued by the typology for Val d'Aran. We do this to see if there are different patterns than the ones we have already seen

# %%
# Create a bar plot. Use a colorblind palette to represent categorical data.
plt.figure(figsize=(8, 4))
hue_order = ["FL", "MU", "RC", "CO"]
colors = ["#0fb5ae", "#4046ca", "#f68511", "#7e84fa"]
customPalette = sns.set_palette(sns.color_palette(colors))
sns.barplot(x='ANY', y='NUM_ACTIONS', hue='TAL_COD_ALARMA2', hue_order = hue_order, data=grouped_by_years_va, palette = customPalette, saturation = 1, width = 0.9)

# Set plot labels and title
plt.xlabel('year')
plt.ylabel('num. rescues')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Save and show the plot
plt.tight_layout()
plt.savefig("figures/rescue_val_d_aran.pdf")
plt.show()

# %% [markdown]
# #### 7.B CPP action in Val d'Aran
# We proceed similarly as we have done for the previous cases

# %%
pam_prot_plans_va = pam_prot_plans[pam_prot_plans["NOM_COMARCA"] == "Aran"].copy().reset_index(drop = True)

# %%
pam_prot_plans_va
# Out:
#    Tipus pla   Nom del pla                         Estat Últim esdeveniment  \
# 0          E    PAM NEUCAT  Homologat pendent de revisió        Homologació
# 1          E  PAM SISMICAT  Homologat pendent de revisió        Homologació
# 2          E   PAM VENTCAT  Homologat pendent de revisió        Homologació
# 3          E  PAM SISMICAT  Homologat pendent de revisió        Homologació
# 4          E   PAM INFOCAT  Homologat pendent de revisió        Homologació
# 5          E    PAM NEUCAT  Homologat pendent de revisió        Homologació
# 6          E  PAM ALLAUCAT  Homologat pendent de revisió        Homologació
# 7          E  PAM ALLAUCAT  Homologat pendent de revisió        Homologació
# 8          E    PAM NEUCAT  Homologat pendent de revisió        Homologació
# 9          E  PAM SISMICAT  Homologat pendent de revisió        Homologació
# 10         E   PAM VENTCAT  Homologat pendent de revisió        Homologació
# 11         E  PAM ALLAUCAT  Homologat pendent de revisió        Homologació
# 12         E   PAM INUNCAT  Homologat pendent de revisió        Homologació
# 13         E  PAM SISMICAT  Homologat pendent de revisió        Homologació
# 14         E   PAM INUNCAT  Homologat pendent de revisió        Homologació
# 15         E   PAM INUNCAT  Homologat pendent de revisió        Homologació
# 16         E   PAM INUNCAT  Homologat pendent de revisió        Homologació
# 17         E    PAM NEUCAT  Homologat pendent de revisió        Homologació
# 18         E   PAM INFOCAT                     Homologat            Revisió
# 19         E  PAM ALLAUCAT                     Homologat            Revisió
# 20         E    PAM NEUCAT                     Homologat            Revisió
# 21         E  PAM SISMICAT                     Homologat            Revisió
# 22         E   PAM INUNCAT                     Homologat            Revisió
# 23         E   PAM VENTCAT                     Homologat            Revisió
#
#    Data de l'últim esdeveniment          Municipi NOM_COMARCA Província
# 0                    2018-12-05           Vilamòs        Aran    Lleida
# 1                    2018-12-05  Vielha e Mijaran        Aran    Lleida
# 2                    2018-12-05             Arres        Aran    Lleida
# 3                    2018-12-05             Arres        Aran    Lleida
# 4                    2018-12-05  Vielha e Mijaran        Aran    Lleida
# 5                    2018-12-05  Vielha e Mijaran        Aran    Lleida
# 6                    2018-12-05            Bòrdes        Aran    Lleida
# 7                    2018-12-05             Arres        Aran    Lleida
# 8                    2018-12-05             Arres        Aran    Lleida
# 9                    2018-12-05           Vilamòs        Aran    Lleida
# 10                   2018-12-05           Vilamòs        Aran    Lleida
# 11                   2018-12-05  Vielha e Mijaran        Aran    Lleida
# 12                   2018-12-05           Vilamòs        Aran    Lleida
# 13                   2018-12-05            Bòrdes        Aran    Lleida
# 14                   2018-12-05  Vielha e Mijaran        Aran    Lleida
# 15                   2018-12-05            Bòrdes        Aran    Lleida
# 16                   2018-12-05             Arres        Aran    Lleida
# 17                   2018-12-05            Bòrdes        Aran    Lleida
# 18                   2022-03-10         Naut Aran        Aran    Lleida
# 19                   2022-03-10         Naut Aran        Aran    Lleida
# 20                   2022-03-10         Naut Aran        Aran    Lleida
# 21                   2022-03-10         Naut Aran        Aran    Lleida
# 22                   2022-03-10         Naut Aran        Aran    Lleida
# 23                   2022-03-10         Naut Aran        Aran    Lleida

# %%
pam_prot_plans_va["Nom del pla"].unique()
# Out:
# array(['PAM NEUCAT', 'PAM SISMICAT', 'PAM VENTCAT', 'PAM INFOCAT',
#        'PAM ALLAUCAT', 'PAM INUNCAT'], dtype=object)

# %%
pam_prot_plans_va["ANY"] = pam_prot_plans_va["Data de l'últim esdeveniment"].dt.year

# %%
grouped_by_years_ccp_va = pam_prot_plans_va.groupby(by = ["ANY", "Nom del pla"]).count().drop(columns = ["Tipus pla", "Últim esdeveniment", "Data de l'últim esdeveniment", "Municipi", "NOM_COMARCA", "Província"])
grouped_by_years_ccp_va
# Out:
#                    Estat
# ANY  Nom del pla
# 2018 PAM ALLAUCAT      3
#      PAM INFOCAT       1
#      PAM INUNCAT       4
#      PAM NEUCAT        4
#      PAM SISMICAT      4
#      PAM VENTCAT       2
# 2022 PAM ALLAUCAT      1
#      PAM INFOCAT       1
#      PAM INUNCAT       1
#      PAM NEUCAT        1
#      PAM SISMICAT      1
#      PAM VENTCAT       1

# %%
# Create a bar plot. Use a colorblind palette to represent categorical data.
from  matplotlib.ticker import FuncFormatter #this is used to set yticks to integers
# Function to format y-axis ticks as integers

plt.figure(figsize=(8, 4))
hue_order = ["PAM INFOCAT", "PAM INUNCAT", "PAM NEUCAT", "PAM SISMICAT", "PAM VENTCAT", "PAM ALLAUCAT"]
alternative_palette = ["#4689ff", "#d02770", "#d3a107", "#09bdb9", "#bbe6fe", "#ba4e00"]
customPalette = sns.set_palette(sns.color_palette(alternative_palette))
sns.barplot(x='ANY', y='Estat', hue='Nom del pla', data=grouped_by_years_ccp_va, hue_order = hue_order ,palette = customPalette, saturation = 1, width = 0.7)

# Set y-axis ticks explicitly to avoid duplication and in integer format
plt.yticks(range(0, int(max(plt.yticks()[0])) + 1))

# Set plot labels and title
plt.xlabel('year')
plt.ylabel('num. mod. CCP')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Save and show the plot
plt.tight_layout()
plt.savefig("figures/cpp_vall_d_aran.pdf")
plt.show()
