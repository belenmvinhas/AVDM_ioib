# %% [markdown]
# # Overview
#
# 1. [__Importing data__](#1)
#     1. [Loading csv files](#1.1)
#
#
# 2. [__Preprocessing data__](#2)
#     1. [Droping NaNs](#2.1)
#     2. [Cleaning dataset](#2.2)
#     3. [Datetime](#2.3)
#     4. [Selecting data (2018-2022)](#2.4)
#
#
# 3. [__Trial plots__](#3)
#     1. [Number of 112 incidents per Catalonia regions](#3.1)
#         1. [Províncies](#3.1.1)
#         2. [Comarques](#3.1.2)
#         3. [Municipis](#3.1.3)
#
#     2. [Time evolution of 112 incidents](#3.2)
#         1. [Grouped by províncies](#3.2.1)
#         2. [Grouped by typology](#3.2.2)

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import seaborn as sns
from datetime import datetime

# %% [markdown]
# # 1. Importing data <a class="anchor" id="1"></a>

# %%
data_dir = "../dades/"
fig_dir = "figures/"

# %% [markdown]
# ## 1.1. Loading csv files <a class="anchor" id="1.1"></a>

# %%
rescue_actions = pd.read_csv(data_dir+"Actuacions_en_salvaments_al_medi_natural_dels_Bombers_de_la_Generalitat_20231109.csv")
protection_plans = pd.read_csv(data_dir+"Registre_general_de_plans_de_protecci__civil_de_Catalunya_20231109.csv")
inc_112 = pd.read_csv(data_dir+"Dades_d_incidents_operatius_gestionats_pel_CAT112_20231110.csv")

# %% [markdown]
# https://analisi.transparenciacatalunya.cat/Seguretat/Actuacions-en-salvaments-al-medi-natural-dels-Bomb/fsum-2k6e
# https://analisi.transparenciacatalunya.cat/Seguretat/Registre-general-de-plans-de-protecci-civil-de-Cat/xqqe-tgav
# https://analisi.transparenciacatalunya.cat/Seguretat/Dades-d-incidents-operatius-gestionats-pel-CAT112/jq8m-d7cw
# https://analisi.transparenciacatalunya.cat/Seguretat/Dades-de-trucades-operatives-gestionades-pel-CAT11/mfqb-sbx4

# %%
comarques = ["Alt Camp","Alt Empordà","Alt Penedès","Alt Urgell","Alta Ribagorça","Anoia","Aran","Bages","Baix Camp",
             "Baix Ebre","Baix Empordà","Baix Llobregat","Baix Penedès","Barcelonès","Berguedà","Cerdanya",
             "Conca de Barberà","Garraf","Garrigues","Garrotxa","Gironès","Maresme","Moianès","Montsià",
             "Noguera","Osona","Pallars Jussà","Pallars Sobirà","Pla d'Urgell","Pla de l'Estany","Priorat",
             "Ribera d'Ebre","Ripollès","Segarra","Segrià","Selva","Solsonès","Tarragonès","Terra Alta",
             "Urgell","Vallès Occidental","Vallès Oriental"]

# %% [markdown]
# # 2. Preprocessing data <a class="anchor" id="2"></a>

# %% [markdown]
# ## 2.1. Dropping NaNs <a class="anchor" id="2.1"></a>

# %% [markdown]
# We only conserve data from Municipal Plans to study them geographically

# %%
rescue_actions.dropna(axis=0, inplace=True)
protection_plans.dropna(axis=0, inplace=True)
inc_112.dropna(axis=0, inplace=True)

# %%
rescue_actions = rescue_actions.reset_index().drop("index",axis=1)
protection_plans = protection_plans.reset_index().drop("index",axis=1)
inc_112 = inc_112.reset_index().drop("index",axis=1)

# %% [markdown]
# # 2.2. Cleaning dataset <a class="anchor" id="2.2"></a>

# %%
inc_112.columns
# Out:
# Index(['ANY', 'MES', 'PROVINCIA', 'COMARCA', 'MUNICIPI', 'TIPUS', 'INCIDENTS'], dtype='object')

# %%
inc_112
# Out:
#          ANY  MES  PROVINCIA            COMARCA           MUNICIPI  \
# 0       2023   10  BARCELONA  VALLES OCCIDENTAL           TERRASSA
# 1       2023   10  BARCELONA    Vallès Oriental      LLIÇA D'AMUNT
# 2       2023   10     GIRONA           Garrotxa               OLOT
# 3       2023   10  TARRAGONA          Baix Camp           ALMOSTER
# 4       2023   10  BARCELONA           Berguedà  CASTELLAR DEL RIU
# ...      ...  ...        ...                ...                ...
# 507684  2014    1     GIRONA        ALT EMPORDA            CAPMANY
# 507685  2014    1     GIRONA              SELVA           VIDRERES
# 507686  2014    1     GIRONA    PLA DE L'ESTANY            CRESPIA
# 507687  2014    1     GIRONA        ALT EMPORDA             LLANÇA
# 507688  2014    1  TARRAGONA          BAIX EBRE           ROQUETES
#
#                TIPUS  INCIDENTS
# 0          Seguretat          1
# 1           Accident          2
# 2            Incendi          6
# 3            Incendi          1
# 4          Seguretat          2
# ...              ...        ...
# 507684     Seguretat          1
# 507685       Incendi          4
# 507686       Incendi          1
# 507687     Seguretat         13
# 507688  Medi ambient          3
#
# [507689 rows x 7 columns]

# %%
tipus_inc = inc_112["TIPUS"].unique()
tipus_inc
# Out:
# array(['Seguretat', 'Accident', 'Incendi', 'Fuita (aigua, gas, altres)',
#        'Meteorologia', 'Altres incidències', 'Assistència sanitària',
#        'Civisme', 'Trànsit', 'Medi ambient'], dtype=object)

# %% [markdown]
# ## 2.3. Datetime <a class="anchor" id="2.3"></a>

# %%
inc_112['ANY'] = inc_112['ANY'].astype(int)
inc_112['MES'] = inc_112['MES'].astype(int)

# %%
inc_112['datetime'] = inc_112.apply(lambda inc_112: datetime(inc_112['ANY'], inc_112['MES'], 1), axis=1)
inc_112 = inc_112.drop(["ANY","MES"], axis=1)

# %% [markdown]
# ## 2.4. Selecting data from 2018 to 2022 <a class="anchor" id="2.4"></a>

# %%
inc_112 = inc_112[(inc_112["datetime"].dt.year >= 2018) & (inc_112["datetime"].dt.year <= 2022)].reset_index()
# Out:
#          index  PROVINCIA           COMARCA                 MUNICIPI  \
# 0        50174  TARRAGONA  CONCA DE BARBERA  SANTA COLOMA DE QUERALT
# 1        50175     LLEIDA      PLA D'URGELL       BELL-LLOC D'URGELL
# 2        50176     GIRONA             SELVA                     OSOR
# 3        50177  BARCELONA   VALLES ORIENTAL    SANT FELIU DE CODINES
# 4        50178     GIRONA          CERDANYA        GUILS DE CERDANYA
# ...        ...        ...               ...                      ...
# 265538  315712  TARRAGONA          ALT CAMP                    VALLS
# 265539  315713  TARRAGONA  CONCA DE BARBERA     PASSANANT I BELLTALL
# 265540  315714     GIRONA           GIRONES          SANT MARTI VELL
# 265541  315715  TARRAGONA         BAIX EBRE                 ROQUETES
# 265542  315716  BARCELONA             BAGES   CASTELLFOLLIT DEL BOIX
#
#                         TIPUS  INCIDENTS   datetime
# 0                     Incendi          1 2022-12-01
# 1                     Incendi          1 2022-12-01
# 2          Altres incidències          1 2022-12-01
# 3                     Incendi          1 2022-12-01
# 4       Assistència sanitària          2 2022-12-01
# ...                       ...        ...        ...
# 265538           Medi ambient          2 2018-01-01
# 265539                Trànsit          4 2018-01-01
# 265540  Assistència sanitària          1 2018-01-01
# 265541                Trànsit         10 2018-01-01
# 265542                Trànsit          1 2018-01-01
#
# [265543 rows x 7 columns]

# %% [markdown]
# ## 2.5. Selecting plans related to protection plans & rescue actions <a class="anchor" id="2.5"></a>

# %%
inc_112["TIPUS"].unique()
# Out:
# array(['Incendi', 'Altres incidències', 'Assistència sanitària',
#        'Medi ambient', 'Accident', 'Trànsit', 'Civisme', 'Seguretat',
#        'Fuita (aigua, gas, altres)', 'Meteorologia'], dtype=object)

# %%
inc_selected = ["Incendi","Accident","Meteorologia","Assistència sanitària"]

inc_112 = inc_112[inc_112["TIPUS"].isin(inc_selected)]

# %%
inc_112
# Out:
#          index  PROVINCIA           COMARCA                 MUNICIPI  \
# 0        50174  TARRAGONA  CONCA DE BARBERA  SANTA COLOMA DE QUERALT
# 1        50175     LLEIDA      PLA D'URGELL       BELL-LLOC D'URGELL
# 3        50177  BARCELONA   VALLES ORIENTAL    SANT FELIU DE CODINES
# 4        50178     GIRONA          CERDANYA        GUILS DE CERDANYA
# 6        50180     GIRONA             SELVA  SANTA COLOMA DE FARNERS
# ...        ...        ...               ...                      ...
# 265524  315698     GIRONA           GIRONES             SANT GREGORI
# 265526  315700  BARCELONA    BAIX LLOBREGAT                MARTORELL
# 265527  315701  TARRAGONA        TARRAGONES               LA SECUITA
# 265534  315708  BARCELONA             BAGES      SANT MATEU DE BAGES
# 265540  315714     GIRONA           GIRONES          SANT MARTI VELL
#
#                         TIPUS  INCIDENTS   datetime
# 0                     Incendi          1 2022-12-01
# 1                     Incendi          1 2022-12-01
# 3                     Incendi          1 2022-12-01
# 4       Assistència sanitària          2 2022-12-01
# 6                    Accident          1 2022-12-01
# ...                       ...        ...        ...
# 265524  Assistència sanitària         11 2018-01-01
# 265526               Accident          3 2018-01-01
# 265527  Assistència sanitària          8 2018-01-01
# 265534                Incendi          1 2018-01-01
# 265540  Assistència sanitària          1 2018-01-01
#
# [96100 rows x 7 columns]

# %% [markdown]
# # 3. Trial plots <a class="anchor" id="3"></a>

# %%
font = 12

# %% [markdown]
# ## 3.1 Number of protection plans activated per Catalonia regions <a class="anchor" id="3.1"></a>

# %% [markdown]
# ### 3.1.1. Províncies <a class="anchor" id="3.1.1"></a>

# %%
cat_prov = gpd.read_file("cat/provincies/divisions-administratives-v2r1-provincies-100000-20230928.shx")
cat_prov
# Out:
#   CODIPROV    NOMPROV    CAPPROV   AREAP5000  \
# 0       08  Barcelona  Barcelona   7730.5077
# 1       17     Girona     Girona   5902.1773
# 2       25     Lleida     Lleida  12165.5722
# 3       43  Tarragona  Tarragona   6305.7083
#
#                                             geometry
# 0  MULTIPOLYGON (((386943.411 4561257.965, 386961...
# 1  MULTIPOLYGON (((482690.024 4613155.364, 482688...
# 2  MULTIPOLYGON (((393371.457 4638570.630, 393374...
# 3  MULTIPOLYGON (((298299.980 4494128.520, 298299...

# %%
inc_112.replace("BARCELONA","Barcelona", inplace=True)
inc_112.replace("LLEIDA","Lleida", inplace=True)
inc_112.replace("TARRAGONA","Tarragona", inplace=True)
inc_112.replace("GIRONA","Girona", inplace=True)
# Out:
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/1832313486.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("BARCELONA","Barcelona", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/1832313486.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("LLEIDA","Lleida", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/1832313486.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("TARRAGONA","Tarragona", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/1832313486.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("GIRONA","Girona", inplace=True)

# %%
ninc_prov = inc_112.groupby('PROVINCIA').size().reset_index(name='# incidents')

# %%
# Merge between shapefile & data
ninc_prov_merge = cat_prov.merge(ninc_prov, how='left', left_on='NOMPROV', right_on='PROVINCIA')

# Conserve original geometry
ninc_prov_merge_gpd = gpd.GeoDataFrame(ninc_prov_merge, geometry="geometry")

# Plot
fig, ax = plt.subplots(figsize=(10,8))
plot = ninc_prov_merge_gpd.plot(column='# incidents',
                                cmap='Blues',
                                norm = LogNorm(),
                                ax=ax,
                                legend=False)

ninc_prov_merge_gpd.boundary.plot(ax=ax, linewidth=0.5, color='black')

cbar = fig.colorbar(plot.get_children()[0], ax=ax, label=r'112 incidents per $\text{província}$')

ax.set_xticks([])
ax.set_yticks([])
ax.set_xticks([])
ax.set_yticks([])

ax.set_aspect('equal')

ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')

ruta = fig_dir+"112_incidents/112_incidents-geo_prov"
plt.savefig(ruta, dpi=500,bbox_inches='tight')

# %% [markdown]
# ### 3.1.2. Comarques <a class="anchor" id="3.1.2"></a>

# %%
cat_comar = gpd.read_file("cat/comarques/divisions-administratives-v2r1-comarques-100000-20220801.shx")
cat_comar
# Out:
#    CODICOMAR           NOMCOMAR                 CAPCOMAR  AREAC5000  \
# 0         01           Alt Camp                    Valls   537.6317
# 1         02        Alt Empordà                 Figueres  1356.6431
# 2         03        Alt Penedès   Vilafranca del Penedès   592.5498
# 3         04         Alt Urgell          la Seu d'Urgell  1447.2028
# 4         05     Alta Ribagorça         el Pont de Suert   427.2234
# 5         06              Anoia                 Igualada   867.0471
# 6         07              Bages                  Manresa  1092.7982
# 7         08          Baix Camp                     Reus   696.4883
# 8         09          Baix Ebre                  Tortosa  1001.9306
# 9         10       Baix Empordà      la Bisbal d'Empordà   701.1353
# 10        11     Baix Llobregat  Sant Feliu de Llobregat   487.4743
# 11        12       Baix Penedès              el Vendrell   296.4311
# 12        13         Barcelonès                Barcelona   146.3935
# 13        14           Berguedà                    Berga  1185.2257
# 14        15           Cerdanya                Puigcerdà   546.4545
# 15        16   Conca de Barberà                Montblanc   650.6021
# 16        17             Garraf     Vilanova i la Geltrú   185.2434
# 17        18          Garrigues      les Borges Blanques   797.2156
# 18        19           Garrotxa                     Olot   733.3229
# 19        20            Gironès                   Girona   575.9353
# 20        21            Maresme                   Mataró   397.9019
# 21        22            Montsià                  Amposta   733.6485
# 22        23            Noguera                 Balaguer  1783.3727
# 23        24              Osona                      Vic  1246.9802
# 24        25      Pallars Jussà                    Tremp  1343.5020
# 25        26     Pallars Sobirà                     Sort  1378.2154
# 26        27       Pla d'Urgell               Mollerussa   305.4285
# 27        28    Pla de l'Estany                 Banyoles   263.3198
# 28        29            Priorat                   Falset   498.0777
# 29        30      Ribera d'Ebre              Móra d'Ebre   827.6182
# 30        31           Ripollès                   Ripoll   956.8939
# 31        32            Segarra                  Cervera   723.5756
# 32        33             Segrià                   Lleida  1396.1161
# 33        34              Selva  Santa Coloma de Farners   994.0428
# 34        35           Solsonès                  Solsona  1000.2169
# 35        36         Tarragonès                Tarragona   320.5849
# 36        37         Terra Alta                  Gandesa   742.6641
# 37        38             Urgell                  Tàrrega   578.2949
# 38        39         Val d'Aran                   Vielha   632.9978
# 39        40  Vallès Occidental      Sabadell / Terrassa   583.0649
# 40        41    Vallès Oriental               Granollers   735.2397
# 41        42            Moianès                     Moià   337.2896
#
#                                              geometry
# 0   POLYGON ((373635.755 4592021.079, 373669.333 4...
# 1   MULTIPOLYGON (((514495.140 4662167.740, 514492...
# 2   POLYGON ((385914.163 4595999.962, 386085.364 4...
# 3   MULTIPOLYGON (((360736.000 4649167.000, 360624...
# 4   POLYGON ((326572.730 4721574.001, 326622.339 4...
# 5   POLYGON ((370158.839 4628885.052, 370282.509 4...
# 6   POLYGON ((417259.067 4646530.811, 417513.903 4...
# 7   MULTIPOLYGON (((335052.970 4547018.980, 335051...
# 8   MULTIPOLYGON (((311847.200 4514855.880, 311833...
# 9   MULTIPOLYGON (((497966.430 4622427.830, 497965...
# 10  POLYGON ((401068.400 4606276.800, 401178.618 4...
# 11  MULTIPOLYGON (((384508.440 4560878.000, 384505...
# 12  MULTIPOLYGON (((430106.350 4576516.340, 430098...
# 13  MULTIPOLYGON (((391614.800 4661923.500, 391606...
# 14  MULTIPOLYGON (((417240.539 4704752.127, 417684...
# 15  POLYGON ((369548.800 4603947.800, 370045.800 4...
# 16  MULTIPOLYGON (((386888.695 4561204.584, 386881...
# 17  POLYGON ((327888.707 4605730.867, 328155.807 4...
# 18  POLYGON ((462306.492 4686925.593, 462315.342 4...
# 19  POLYGON ((494081.526 4662565.750, 494214.686 4...
# 20  POLYGON ((477054.900 4621435.100, 478728.500 4...
# 21  MULTIPOLYGON (((298299.980 4494128.520, 298299...
# 22  POLYGON ((348524.976 4664596.302, 348400.341 4...
# 23  MULTIPOLYGON (((418580.652 4643167.275, 418307...
# 24  MULTIPOLYGON (((317718.105 4693389.714, 317738...
# 25  POLYGON ((343217.247 4738499.818, 343225.151 4...
# 26  MULTIPOLYGON (((341924.700 4618515.800, 341260...
# 27  POLYGON ((482120.535 4672805.481, 482191.594 4...
# 28  POLYGON ((320525.200 4579659.500, 321213.700 4...
# 29  POLYGON ((288368.413 4578209.165, 288383.230 4...
# 30  MULTIPOLYGON (((419785.996 4664417.149, 419923...
# 31  POLYGON ((365993.100 4642951.900, 366072.200 4...
# 32  MULTIPOLYGON (((316312.768 4606506.701, 315561...
# 33  MULTIPOLYGON (((482690.024 4613155.364, 482688...
# 34  MULTIPOLYGON (((393371.457 4638570.630, 393374...
# 35  MULTIPOLYGON (((363274.620 4554494.750, 363220...
# 36  POLYGON ((280206.273 4568311.294, 280325.826 4...
# 37  MULTIPOLYGON (((330423.400 4623950.100, 329861...
# 38  POLYGON ((313407.046 4747612.147, 313430.255 4...
# 39  POLYGON ((426549.300 4618464.000, 427202.000 4...
# 40  POLYGON ((449099.721 4628266.206, 449108.947 4...
# 41  POLYGON ((428837.859 4639478.022, 428961.755 4...

# %%
inc_112["COMARCA"].unique()
# Out:
# array(['CONCA DE BARBERA', "PLA D'URGELL", 'VALLES ORIENTAL', 'CERDANYA',
#        'SELVA', 'ALT CAMP', 'VALLES OCCIDENTAL', 'MONTSIA',
#        'BAIX PENEDES', 'SEGRIA', 'OSONA', 'NOGUERA', 'GIRONES',
#        'BAIX EMPORDA', 'ALT PENEDES', 'BERGUEDA', 'MARESME', 'BAIX CAMP',
#        'GARRIGUES', 'GARRAF', 'TARRAGONES', "VAL D'ARAN", 'PRIORAT',
#        'ALT URGELL', 'BARCELONES', 'BAIX EBRE', 'ALT EMPORDA', 'RIPOLLES',
#        'GARROTXA', 'BAGES', 'BAIX LLOBREGAT', 'PALLARS JUSSA', 'ANOIA',
#        'SEGARRA', 'TERRA ALTA', "RIBERA D'EBRE", 'SOLSONES',
#        'ALTA RIBAGORÇA', 'URGELL', 'PALLARS SOBIRA', 'MOIANES',
#        "PLA DE L'ESTANY"], dtype=object)

# %%
inc_112.replace("CONCA DE BARBERA","Conca de Barberà", inplace=True)
inc_112.replace("PLA D'URGELL","Pla d'Urgell", inplace=True)
inc_112.replace("SELVA","Selva", inplace=True)
inc_112.replace("VALLES ORIENTAL","Vallès Oriental", inplace=True)
inc_112.replace("CERDANYA","Cerdanya", inplace=True)
inc_112.replace("ANOIA","Anoia", inplace=True)
inc_112.replace("ALT CAMP","Alt Camp", inplace=True)
inc_112.replace("VALLES OCCIDENTAL","Vallès Occidental", inplace=True)
inc_112.replace("MONTSIA","Montsià", inplace=True)
inc_112.replace("SEGRIA","Segrià", inplace=True)
inc_112.replace("GARROTXA","Garrotxa", inplace=True)
inc_112.replace("BAIX PENEDES","Baix Penedès", inplace=True)
inc_112.replace("GIRONES","Gironès", inplace=True)
inc_112.replace("OSONA","Osona", inplace=True)
inc_112.replace("BAIX LLOBREGAT","Baix Llobregat", inplace=True)
inc_112.replace("ALT URGELL","Alt Urgell", inplace=True)
inc_112.replace("NOGUERA","Noguera", inplace=True)
inc_112.replace("MARESME","Maresme", inplace=True)
inc_112.replace("ALT EMPORDA","Alt Empordà", inplace=True)
inc_112.replace("BAIX EMPORDA","Baix Empordà", inplace=True)
inc_112.replace("ALT PENEDES","Alt Penedès", inplace=True)
inc_112.replace("SOLSONES","Solsonès", inplace=True)
inc_112.replace("TARRAGONES","Tarragonès", inplace=True)
inc_112.replace("RIBERA D'EBRE","Ribera d'Ebre", inplace=True)
inc_112.replace("GARRAF","Garraf", inplace=True)
inc_112.replace("PALLARS SOBIRA","Pallars Sobirà", inplace=True)
inc_112.replace("BERGUEDA","Berguedà", inplace=True)
inc_112.replace("BAGES","Bages", inplace=True)
inc_112.replace("BAIX CAMP","Baix Camp", inplace=True)
inc_112.replace("GARRIGUES","Garrigues", inplace=True)
inc_112.replace("BAIX EBRE","Baix Ebre", inplace=True)
inc_112.replace("SEGARRA","Segarra", inplace=True)
inc_112.replace("PLA DE L'ESTANY","Pla de l'Estany", inplace=True)
inc_112.replace("PRIORAT","Priorat", inplace=True)
inc_112.replace("VAL D'ARAN","Val d'Aran", inplace=True)
inc_112.replace("BARCELONES","Barcelonès", inplace=True)
inc_112.replace("URGELL","Urgell", inplace=True)
inc_112.replace("RIPOLLES","Ripollès", inplace=True)
inc_112.replace("ALTA RIBAGORÇA","Alta Ribagorça", inplace=True)
inc_112.replace("TERRA ALTA","Terra Alta", inplace=True)
inc_112.replace("MOIANES","Moianès", inplace=True)
inc_112.replace("PALLARS JUSSA","Pallars Jussà", inplace=True)
# Out:
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("CONCA DE BARBERA","Conca de Barberà", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("PLA D'URGELL","Pla d'Urgell", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("SELVA","Selva", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("VALLES ORIENTAL","Vallès Oriental", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("CERDANYA","Cerdanya", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("ANOIA","Anoia", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("ALT CAMP","Alt Camp", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("VALLES OCCIDENTAL","Vallès Occidental", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("MONTSIA","Montsià", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("SEGRIA","Segrià", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("GARROTXA","Garrotxa", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("BAIX PENEDES","Baix Penedès", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("GIRONES","Gironès", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("OSONA","Osona", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("BAIX LLOBREGAT","Baix Llobregat", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("ALT URGELL","Alt Urgell", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("NOGUERA","Noguera", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("MARESME","Maresme", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("ALT EMPORDA","Alt Empordà", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("BAIX EMPORDA","Baix Empordà", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("ALT PENEDES","Alt Penedès", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("SOLSONES","Solsonès", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("TARRAGONES","Tarragonès", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("RIBERA D'EBRE","Ribera d'Ebre", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("GARRAF","Garraf", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("PALLARS SOBIRA","Pallars Sobirà", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("BERGUEDA","Berguedà", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("BAGES","Bages", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("BAIX CAMP","Baix Camp", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("GARRIGUES","Garrigues", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("BAIX EBRE","Baix Ebre", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("SEGARRA","Segarra", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("PLA DE L'ESTANY","Pla de l'Estany", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("PRIORAT","Priorat", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("VAL D'ARAN","Val d'Aran", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("BARCELONES","Barcelonès", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("URGELL","Urgell", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("RIPOLLES","Ripollès", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("ALTA RIBAGORÇA","Alta Ribagorça", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("TERRA ALTA","Terra Alta", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("MOIANES","Moianès", inplace=True)
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/751147001.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inc_112.replace("PALLARS JUSSA","Pallars Jussà", inplace=True)

# %%
inc_112["COMARCA"].unique()
# Out:
# array(['Conca de Barberà', "Pla d'Urgell", 'Vallès Oriental', 'Cerdanya',
#        'Selva', 'Alt Camp', 'Vallès Occidental', 'Montsià',
#        'Baix Penedès', 'Segrià', 'Osona', 'Noguera', 'Gironès',
#        'Baix Empordà', 'Alt Penedès', 'Berguedà', 'Maresme', 'Baix Camp',
#        'Garrigues', 'Garraf', 'Tarragonès', "Val d'Aran", 'Priorat',
#        'Alt Urgell', 'Barcelonès', 'Baix Ebre', 'Alt Empordà', 'Ripollès',
#        'Garrotxa', 'Bages', 'Baix Llobregat', 'Pallars Jussà', 'Anoia',
#        'Segarra', 'Terra Alta', "Ribera d'Ebre", 'Solsonès',
#        'Alta Ribagorça', 'Urgell', 'Pallars Sobirà', 'Moianès',
#        "Pla de l'Estany"], dtype=object)

# %%
ninc_comar = inc_112.groupby('COMARCA').size().reset_index(name='# incidents')

# %%
# Merge between shapefile & data
ninc_comar_merge = cat_comar.merge(ninc_comar, how='left', left_on='NOMCOMAR', right_on='COMARCA')

# Conserve original geometry
ninc_comar_merge_gpd = gpd.GeoDataFrame(ninc_comar_merge, geometry="geometry")


# Plot
fig, ax = plt.subplots(figsize=(10,8))
plot = ninc_comar_merge_gpd.plot(column='# incidents',
                                 cmap='Blues',
                                 norm = LogNorm(),
                                 ax=ax,
                                 legend=False)

ninc_comar_merge_gpd.boundary.plot(ax=ax, linewidth=0.5, color='black')

cbar = fig.colorbar(plot.get_children()[0], ax=ax, label=r'112 incidents per $\text{comarca}$')

ax.set_xticks([])
ax.set_yticks([])

ax.set_xticks([])
ax.set_yticks([])

ax.set_aspect('equal')

ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')

ruta = fig_dir+"112_incidents/112_incidents-geo_comar"
plt.savefig(ruta, dpi=500,bbox_inches='tight')

# %% [markdown]
# ### 3.1.3. Municipis <a class="anchor" id="3.1.3"></a>

# %%
ninc_muni = inc_112.groupby('MUNICIPI').size().reset_index(name='# incidents')

# %%
cat_muni = gpd.read_file("cat/municipis/divisions-administratives-v2r1-municipis-100000-20230928.shx")
cat_muni.head()
# Out:
#   CODIMUNI             NOMMUNI             CAPMUNI   AREAM5000 CODICOMAR  \
# 0   250019  Abella de la Conca  Abella de la Conca   77.970100        25
# 1   080018              Abrera              Abrera   19.978100        11
# 2   250024                Àger                Àger  160.202600        23
# 3   250030            Agramunt            Agramunt   79.359535        38
# 4   080023  Aguilar de Segarra  Aguilar de Segarra   43.219825        07
#
#          NOMCOMAR                 CAPCOMAR CODIVEGUE           NOMVEGUE  \
# 0   Pallars Jussà                    Tremp        06        Alt Pirineu
# 1  Baix Llobregat  Sant Feliu de Llobregat        01          Barcelona
# 2         Noguera                 Balaguer        03             Lleida
# 3          Urgell                  Tàrrega        03             Lleida
# 4           Bages                  Manresa        07  Catalunya Central
#
#     CAPVEGUE CODIPROV    NOMPROV    CAPPROV  \
# 0          *       25     Lleida     Lleida
# 1  Barcelona       08  Barcelona  Barcelona
# 2     Lleida       25     Lleida     Lleida
# 3     Lleida       25     Lleida     Lleida
# 4          *       08  Barcelona  Barcelona
#
#                                             geometry
# 0  POLYGON ((346678.012 4677003.965, 346688.592 4...
# 1  POLYGON ((410315.500 4598888.500, 410888.800 4...
# 2  POLYGON ((308157.549 4660767.518, 308220.898 4...
# 3  MULTIPOLYGON (((342659.900 4635474.900, 342566...
# 4  POLYGON ((384343.603 4625174.347, 384397.036 4...

# %%
import unicodedata

def noaccents(input_string):
    nfkd_form = unicodedata.normalize('NFKD', input_string)
    return ''.join([c for c in nfkd_form if not unicodedata.combining(c)])

def shift_noaccents(input_string):
    string_sin_tildes = noaccents(input_string)
    return string_sin_tildes.upper()


for i in range(0,len(cat_muni["NOMMUNI"])):
    cat_muni["NOMMUNI"][i] = shift_noaccents(cat_muni["NOMMUNI"][i])

cat_muni.head()
# Out:
# /var/folders/93/12z5kvyx445470bf3l70prdc0000gn/T/ipykernel_85558/1880096432.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_muni["NOMMUNI"][i] = shift_noaccents(cat_muni["NOMMUNI"][i])
#   CODIMUNI             NOMMUNI             CAPMUNI   AREAM5000 CODICOMAR  \
# 0   250019  ABELLA DE LA CONCA  Abella de la Conca   77.970100        25
# 1   080018              ABRERA              Abrera   19.978100        11
# 2   250024                AGER                Àger  160.202600        23
# 3   250030            AGRAMUNT            Agramunt   79.359535        38
# 4   080023  AGUILAR DE SEGARRA  Aguilar de Segarra   43.219825        07
#
#          NOMCOMAR                 CAPCOMAR CODIVEGUE           NOMVEGUE  \
# 0   Pallars Jussà                    Tremp        06        Alt Pirineu
# 1  Baix Llobregat  Sant Feliu de Llobregat        01          Barcelona
# 2         Noguera                 Balaguer        03             Lleida
# 3          Urgell                  Tàrrega        03             Lleida
# 4           Bages                  Manresa        07  Catalunya Central
#
#     CAPVEGUE CODIPROV    NOMPROV    CAPPROV  \
# 0          *       25     Lleida     Lleida
# 1  Barcelona       08  Barcelona  Barcelona
# 2     Lleida       25     Lleida     Lleida
# 3     Lleida       25     Lleida     Lleida
# 4          *       08  Barcelona  Barcelona
#
#                                             geometry
# 0  POLYGON ((346678.012 4677003.965, 346688.592 4...
# 1  POLYGON ((410315.500 4598888.500, 410888.800 4...
# 2  POLYGON ((308157.549 4660767.518, 308220.898 4...
# 3  MULTIPOLYGON (((342659.900 4635474.900, 342566...
# 4  POLYGON ((384343.603 4625174.347, 384397.036 4...

# %%
# Merge between shapefile & data
ninc_muni_merge = cat_muni.merge(ninc_muni, how='left', left_on='NOMMUNI', right_on='MUNICIPI')

# Conserve original geometry
ninc_muni_merge_gpd = gpd.GeoDataFrame(ninc_muni_merge, geometry="geometry")

# Plot
fig, ax = plt.subplots(figsize=(10,8))

plot = ninc_muni_merge_gpd.plot(column='# incidents',
                                cmap='Blues',
                                norm = LogNorm(),
                                ax=ax,
                                legend=False)

ninc_muni_merge_gpd.boundary.plot(ax=ax, linewidth=0.5, color='black')

cbar = fig.colorbar(plot.get_children()[0], ax=ax, label=r'112 incidents per $\text{municipi}$')

ax.set_xticks([])
ax.set_yticks([])

ax.set_aspect('equal')

ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')

ruta = fig_dir+"112_incidents/112_incidents-geo_muni"
plt.savefig(ruta, dpi=500,bbox_inches='tight')

# %% [markdown]
# ## 3.2. Time evolution of 112 incidents <a class="anchor" id="3.2"></a>

# %% [markdown]
# ### 3.2.1. Grouped by províncies  <a class="anchor" id="3.2.1"></a>

# %%
ninc_prov = pd.DataFrame({"PROVINCIA":[],"# incidents":[],"year":[]})

selected_years = np.arange(2018,2023)

for i in range(len(selected_years)):
    inc_112_year = inc_112[(inc_112["datetime"].dt.year == selected_years[i])]
    ninc_year_prov = inc_112_year.groupby('PROVINCIA').size().reset_index(name=f'# incidents')
    ninc_year_prov["year"] = int(selected_years[i])
    
    ninc_prov = pd.concat([ninc_prov,ninc_year_prov])

# %%
ninc_prov["year"] = ninc_prov["year"].astype(int)
ninc_prov["# incidents"] = ninc_prov["# incidents"].astype(int)
ninc_prov
# Out:
#    PROVINCIA  # incidents  year
# 0  Barcelona         7646  2018
# 1     Girona         4284  2018
# 2     Lleida         3119  2018
# 3  Tarragona         3674  2018
# 0  Barcelona         7781  2019
# 1     Girona         4346  2019
# 2     Lleida         3325  2019
# 3  Tarragona         3796  2019
# 0  Barcelona         7745  2020
# 1     Girona         4294  2020
# 2     Lleida         3365  2020
# 3  Tarragona         3646  2020
# 0  Barcelona         7712  2021
# 1     Girona         4327  2021
# 2     Lleida         3566  2021
# 3  Tarragona         3903  2021
# 0  Barcelona         7741  2022
# 1     Girona         4438  2022
# 2     Lleida         3632  2022
# 3  Tarragona         3760  2022

# %%
plt.figure(figsize=(8, 6))

sns.barplot(data=ninc_prov,  x="year",y="# incidents", hue="PROVINCIA", dodge=True)

ruta = fig_dir+"112_incidents/112_incidents-year_prov"
plt.savefig(ruta, dpi=500,bbox_inches='tight')

# %% [markdown]
# ### 3.2.2. Grouped by typology  <a class="anchor" id="3.2.2"></a>

# %%
ninc_type_prov = inc_112.groupby(['TIPUS',"PROVINCIA"]).size().reset_index(name='# incidents')
ninc_type_prov
# Out:
#                     TIPUS  PROVINCIA  # incidents
# 0                Accident  Barcelona         7399
# 1                Accident     Girona         3283
# 2                Accident     Lleida         2126
# 3                Accident  Tarragona         2578
# 4   Assistència sanitària  Barcelona        16309
# 5   Assistència sanitària     Girona        10957
# 6   Assistència sanitària     Lleida         9276
# 7   Assistència sanitària  Tarragona         9084
# 8                 Incendi  Barcelona        12032
# 9                 Incendi     Girona         6368
# 10                Incendi     Lleida         5133
# 11                Incendi  Tarragona         5954
# 12           Meteorologia  Barcelona         2885
# 13           Meteorologia     Girona         1081
# 14           Meteorologia     Lleida          472
# 15           Meteorologia  Tarragona         1163

# %%
plt.figure(figsize=(10, 5))

sns.barplot(data=ninc_type_prov,  x="TIPUS",y="# incidents", hue="PROVINCIA", dodge=True)

plt.xticks(rotation = 90)

ruta = fig_dir+"112_incidents/112_incidents-type_prov"
plt.savefig(ruta, dpi=500,bbox_inches='tight')
